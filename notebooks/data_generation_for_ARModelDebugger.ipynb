# %% [markdown]
# ## Input data: Model outputs
# This data comes from scratch/XXXXXXX/Vis/output/
#
# It contains a folder for each skill (e.g., M2, M4, etc). Each folder contains multiple .npz files that represents the sessions. ``<video_id>``-features.npz files contain the features extracted from each video (session).
# Features contain the following keys: ``['fps', 'window_limit', 'omnivore', 'slowfast', 'avion', 'objects_conf', 'objects_bbox', 'hls_l_avg', 'window_medoid']``

# %% [markdown]
# ### Testing

# %%
import numpy as np
import math

user_path = "/Users/soniacq/PTG/BBN_data/updated_models/output/R19/"
# scp -r scqXXX@greene.hpc.nyu.edu:/scratch/XXXXXXX/data/BBN/features/M2/aug_img_perc0.8_NEW-YOLO_weighted_loss .
path_original_data = user_path # + 'BBN_data/RNN/aug_img_perc0.8_NEW-YOLO_weighted_loss/'
# Load the .npy file with allow_pickle=True
features_M2_1 = np.load(path_original_data + 'R19-20-features.npz', allow_pickle=True)

# Load the .npy file with allow_pickle=True
# labels_M2_1 = np.load(path_original_data + '3_tourns_2-window_label.npz', allow_pickle=True)

# %%
# Get the keys and convert them to a list
keys = list(features_M2_1.keys())
# Print the keys
print(keys)
# # Get the keys and convert them to a list
# keys_labels = list(labels_M2_1.keys())
# # Print the keys
# print(keys_labels)
# Out:
# ['fps', 'window_limit', 'omnivore', 'slowfast', 'avion', 'objects_conf', 'objects_bbox', 'hls_l_avg', 'window_medoid', 'objects_class', 'label', 'label_desc']

# %%
temp = ['No Step'] * features_M2_1['window_medoid'].shape[0] if features_M2_1['label'].shape[0] == 0 else features_M2_1['label']
max(np.unique(temp))
# Out:
# 6

# %%
features_M2_1['window_medoid']
# Out:
# array([   1,   11,   28,   63,   82,  120,  139,  188,  217,  234,  255,
#         324,  314,  363,  396,  429,  451,  496,  495,  539,  583,  592,
#         634,  669,  673,  706,  734,  780,  818,  848,  869,  894,  914,
#         982,  999, 1007, 1056, 1103, 1117, 1125, 1167, 1215, 1222, 1240,
#        1292, 1324, 1355, 1381, 1386, 1442, 1468])

# %%
omnivore_features = features_M2_1['omnivore']
print(features_M2_1['omnivore'].shape)
print(features_M2_1['slowfast'].shape)
print(features_M2_1['avion'].shape)

# array_labels = labels_M2_1['label_desc']
# print(len(array_labels))
# Out:
# (51, 1024)
# (51, 1600)
# (51, 3806)

# %%
window_limit_data = features_M2_1['window_limit']
n_window_frames = window_limit_data.shape[0]-1
last_IDframe = window_limit_data[n_window_frames][1]
video_duration = round(last_IDframe/features_M2_1['fps'].item()) # Use round() to round a number to the nearest integer
print("n_window_frames:", n_window_frames)
print("last_IDframe:", last_IDframe)
print("video_duration:", video_duration)
# Out:
# n_window_frames: 50
# last_IDframe: 1495
# video_duration: 50

# %%
window_limit_data.shape[0]
# Out:
# 51

# %% [markdown]
# ## Generate session metadata

# %%
import os
import numpy as np
import json

def compute_video_metadata(npz_file_path):
    features = np.load(npz_file_path, allow_pickle=True)
    window_limit_data = features['window_limit']
    n_window_frames = window_limit_data.shape[0] - 1
    last_IDframe = window_limit_data[n_window_frames][1]
    label = [0] * features['window_medoid'].shape[0] if features['label'].shape[0] == 0 else features['label']
    label_desc = ['No step'] * features['window_medoid'].shape[0] if features['label_desc'].shape[0] == 0 else features['label_desc']
    fps = features['fps'].item()
    duration_seconds = round(last_IDframe / fps)
    
    
    return {
        "duration_seconds": duration_seconds,
        "numberof_window_frames": n_window_frames,
        "last_IDframe": int(last_IDframe),
        "total_labels": int(len(np.unique(label))),
        "max_id_labels": int(max(np.unique(label))),
        "unique_labels": str(np.unique(label_desc)),
        "unique_id_labels": str(np.unique(label))
    }

def generate_json(directory):
    data = {}
    
    for skill_name in os.listdir(directory):
        skill_path = os.path.join(directory, skill_name)
        if os.path.isdir(skill_path):
            skill_data = {}
            for file_name in os.listdir(skill_path):
                if file_name.endswith('-features.npz'):
                    video_id = file_name.split('-features.npz')[0]
                    file_path = os.path.join(skill_path, file_name)
                    video_metadata = compute_video_metadata(file_path)
                    skill_data[video_id] = video_metadata
            if skill_data:
                data[skill_name] = skill_data

    return data

def save_json(data, output_file):
    with open(output_file, 'w') as json_file:
        json.dump(data, json_file, indent=4)

# Example usage in a Jupyter notebook
directory = "/Users/soniacq/PTG/BBN_data/updated_models/output/"  # Replace with the path to the directory containing the skill folders
output_file = "/Users/soniacq/PTG/BBN_data/updated_models/output/sessions_metadata.json"            # Replace with the desired output file path
result = generate_json(directory)
save_json(result, output_file)
print("JSON file generated successfully.")
# Out:
# JSON file generated successfully.

# %% [markdown]
# ## Generate data for each window_frame for each corresponging session

# %%
import os
import numpy as np
import json


def generate_detailed_json(directory):
    data = []
    
    for skill_name in os.listdir(directory):
        skill_path = os.path.join(directory, skill_name)
        if os.path.isdir(skill_path):
            for file_name in os.listdir(skill_path):
                if file_name.endswith('-features.npz'):
                    video_id = file_name.split('-features.npz')[0]
                    file_path = os.path.join(skill_path, file_name)
                    features = np.load(file_path, allow_pickle=True)
                    
                    keys = list(features.keys())
                    # Print the keys
                    hls_l_avg = features['hls_l_avg']
                    label = [0] * features['window_medoid'].shape[0] if features['label'].shape[0] == 0 else features['label']
                    label_desc = ['No step'] * features['window_medoid'].shape[0] if features['label_desc'].shape[0] == 0 else features['label_desc']
                    objects_bbox = features['objects_bbox']
                    objects_conf = features['objects_conf']
                    frame_id = features['window_medoid']
                    
                    trial_data = []
                    
                    for i in range(len(hls_l_avg)):
                        window_data = {
                            "seconds": i,
                            "hls_lightness_avg": float(hls_l_avg[i]),
                            "step": float(label[i]),
                            "step_desc": label_desc[i],
                            "objects_bbox": objects_bbox[i].tolist(),
                            "objects_conf": objects_conf[i].tolist(),
                            # "objects_conf_avg": float(np.mean(objects_conf[i]))
                            "objects_conf_avg": float(np.mean(objects_conf[i])) if len(objects_conf[i]) > 0 else -1,
                            "frame_id": str(frame_id[i])
                        }
                        trial_data.append(window_data)
                    
                    subject_data = {
                        "skill_id": skill_name,
                        "session_id": video_id,
                        "data": trial_data
                    }
                    
                    data.append(subject_data)
    
    return data

def save_json(data, output_file):
    with open(output_file, 'w') as json_file:
        json.dump(data, json_file, indent=4)

# Example usage in a Jupyter notebook
directory = "/Users/soniacq/PTG/BBN_data/updated_models/output/"  # Replace with the path to the directory containing the skill folders
output_file = "/Users/soniacq/PTG/BBN_data/updated_models/output/sessions_window_frame_data.json"            # Replace with the desired output file path
result = generate_detailed_json(directory)
save_json(result, output_file)
print("JSON file generated successfully.")
# Out:
# JSON file generated successfully.

# %% [markdown]
# ### Save t-SNE resutls

# %% [markdown]
# #### tsne position for all sessions

# %%
import os
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE

def load_features(file_path):
    features = np.load(file_path, allow_pickle=True)
    omnivore = features['omnivore']
    slowfast = features['slowfast']
    avion = features['avion']
    window_medoid = features['window_medoid']
    objects_class = features['objects_class']
    objects_conf = features['objects_conf']
    step_label = [0] * features['window_medoid'].shape[0] if features['label'].shape[0] == 0 else features['label']
    step_label_desc = ['No step'] * features['window_medoid'].shape[0] if features['label_desc'].shape[0] == 0 else features['label_desc']
    
    return omnivore, slowfast, avion, window_medoid, objects_class, objects_conf, step_label, step_label_desc

def apply_tsne(features, metadata):
    tsne = TSNE(n_components=2, random_state=42)
    tsne_results = tsne.fit_transform(features)
    data = []
    for i, (x, y) in enumerate(tsne_results):
        data.append({
            "id": metadata[i]['id'],
            "session_id": metadata[i]['session_id'],
            "frame_id": metadata[i]['frame_id'],
            "objects_class": metadata[i]['objects_class'],
            "objects_conf": metadata[i]['objects_conf'],
            "step_label": metadata[i]['step_label'],
            "step_label_desc": metadata[i]['step_label_desc'],
            "x": float(x),  # Convert to native Python float
            "y": float(y),  # Convert to native Python float
            "method": metadata[i]['method'],
            "session": metadata[i]['session'],
            "skill": metadata[i]['skill']
        })
    return data

def generate_csv(directory, output_file):
    all_omnivore_features = []
    all_slowfast_features = []
    all_avion_features = []
    
    omnivore_labels = []
    slowfast_labels = []
    avion_labels = []
    
    for skill_name in os.listdir(directory):
        skill_path = os.path.join(directory, skill_name)
        if os.path.isdir(skill_path):
            for file_name in os.listdir(skill_path):
                if file_name.endswith('-features.npz'):
                    video_id = file_name.split('-features.npz')[0]
                    file_path = os.path.join(skill_path, file_name)
                    omnivore, slowfast, avion, window_medoid, objects_class, objects_conf, step_label, step_label_desc = load_features(file_path)
                    
                    session_length = len(omnivore) + len(slowfast) + len(avion)
                    current_session_id = 0
                    for i in range(len(omnivore)):
                        omnivore_labels.append({"id": len(omnivore_labels), "session_id": current_session_id, "frame_id": window_medoid[i], "objects_class": objects_class[i], "objects_conf": objects_conf[i], "step_label": step_label[i],"step_label_desc": step_label_desc[i], "method": 'omnivore', "session": video_id, "skill": skill_name})
                        current_session_id += 1
                    current_session_id = 0
                    for i in range(len(slowfast)):
                        slowfast_labels.append({"id": len(slowfast_labels), "session_id": current_session_id, "frame_id": window_medoid[i], "objects_class": objects_class[i], "objects_conf": objects_conf[i], "step_label": step_label[i],"step_label_desc": step_label_desc[i], "method": 'slowfast', "session": video_id, "skill": skill_name})
                        current_session_id += 1
                    current_session_id = 0
                    for i in range(len(avion)):
                        avion_labels.append({"id": len(avion_labels), "session_id": current_session_id, "frame_id": window_medoid[i], "objects_class": objects_class[i], "objects_conf": objects_conf[i], "step_label": step_label[i],"step_label_desc": step_label_desc[i], "method": 'avion', "session": video_id, "skill": skill_name})
                        current_session_id += 1
                    
                    all_omnivore_features.append(omnivore)
                    all_slowfast_features.append(slowfast)
                    all_avion_features.append(avion)
    
    # Concatenate all features
    all_omnivore_features = np.concatenate(all_omnivore_features)
    all_slowfast_features = np.concatenate(all_slowfast_features)
    all_avion_features = np.concatenate(all_avion_features)
    
    # Apply t-SNE on the concatenated features
    omnivore_data = apply_tsne(all_omnivore_features, omnivore_labels)
    slowfast_data = apply_tsne(all_slowfast_features, slowfast_labels)
    avion_data = apply_tsne(all_avion_features, avion_labels)
    
    # Combine all data
    all_data = omnivore_data + slowfast_data + avion_data
    
    # Save to CSV
    df = pd.DataFrame(all_data)
    df.to_csv(output_file, index=False)
    print(f"CSV file generated successfully: {output_file}")
    return all_data

# Example usage in a Jupyter notebook
directory = "/Users/soniacq/PTG/BBN_data/updated_models/output_sample/"  # Replace with the path to the directory containing the skill folders
output_file = "/Users/soniacq/PTG/BBN_data/updated_models/output_sample/all_sessions_tsne_results_10.csv"  # Replace with the desired output file path
all_data = generate_csv(directory, output_file)
# Out:
# CSV file generated successfully: /Users/soniacq/PTG/BBN_data/updated_models/output_sample/all_sessions_tsne_results_10.csv

# %%
import numpy as np
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.cluster import KMeans
import json

def compute_silhouette_scores(data):
    print("Hello")
    # Initialize results dictionary
    results = {}
    
    # Get unique methods
    methods = set(d['method'] for d in data)
    
    for method in methods:
        # Filter data based on the method
        method_data = [d for d in data if d['method'] == method]
        
        # Extract x, y positions and skill labels
        positions = np.array([(d['x'], d['y']) for d in method_data])
        labels = np.array([d['skill'] for d in method_data])
        print(labels)
        # Ensure there are at least two unique labels
        if len(set(labels)) > 1:
            # Compute overall silhouette score and boxplot statistics
            silhouette_values = silhouette_samples(positions, labels, metric='euclidean')
            average_score = silhouette_score(positions, labels, metric='euclidean')
            boxplot_stats = calculate_boxplot_stats(silhouette_values)
            
            # Initialize method results
            method_results = {
                'average_score': average_score,
                'boxplot': boxplot_stats,
                'skills': {}
            }
            
            # Calculate silhouette score for each skill (individual class)
            skills = set(labels)
            for skill in skills:
                # Filter data for the specific skill
                skill_data = np.array([pos for pos, lbl in zip(positions, labels) if lbl == skill])
                
                # Apply KMeans clustering to get cluster labels for skill data
                if len(skill_data) > 1:
                    kmeans = KMeans(n_clusters=2, random_state=0).fit(skill_data)
                    skill_labels = kmeans.labels_
                    
                    # Compute silhouette score for skill data
                    skill_silhouette_values = silhouette_samples(skill_data, skill_labels, metric='euclidean')
                    skill_average_score = silhouette_score(skill_data, skill_labels, metric='euclidean')
                    skill_boxplot_stats = calculate_boxplot_stats(skill_silhouette_values)
                    
                    # Store skill results
                    method_results['skills'][skill] = {
                        'average_score': skill_average_score,
                        'boxplot': skill_boxplot_stats
                    }
            
            # Store method results in the main results dictionary
            results[method] = method_results
    
    # Save results to a JSON file
    with open('/Users/soniacq/PTG/BBN_data/updated_models/output_sample/silhouette_scores.json', 'w') as outfile:
        json.dump(results, outfile, indent=4)
    
    return results

def calculate_boxplot_stats(data):
    # Sort data
    sorted_data = np.sort(data)
    
    # Calculate quartiles
    q1 = np.percentile(sorted_data, 25)
    median = np.percentile(sorted_data, 50)
    q3 = np.percentile(sorted_data, 75)
    min_value = sorted_data[0]
    max_value = sorted_data[-1]
    
    return {
        'min': min_value,
        'q1': q1,
        'median': median,
        'q3': q3,
        'max': max_value
    }

# Compute silhouette scores and save to JSON
results = compute_silhouette_scores(all_data)

results
# Out:
# Hello
# ['M1' 'M1' 'M1' ... 'R16' 'R16' 'R16']
# ['M1' 'M1' 'M1' ... 'R16' 'R16' 'R16']
# ['M1' 'M1' 'M1' ... 'R16' 'R16' 'R16']
# {'slowfast': {'average_score': 0.17968376813499823,
#   'boxplot': {'min': -0.7484903155364779,
#    'q1': -0.1215255398771232,
#    'median': 0.3017885213558181,
#    'q3': 0.5220592075813169,
#    'max': 0.6567077461883581},
#   'skills': {'M3': {'average_score': 0.6971652553913619,
#     'boxplot': {'min': 0.12099854622297176,
#      'q1': 0.6276702100699263,
#      'median': 0.7109426338038809,
#      'q3': 0.7780003123415153,
#      'max': 0.8230749474151335}},
#    'M1': {'average_score': 0.44872824561176927,
#     'boxplot': {'min': 0.011255101718318634,
#      'q1': 0.41938478591930123,
#      'median': 0.46865028763614097,
#      'q3': 0.5344536851174243,
#      'max': 0.5819642654360723}},
#    'R18': {'average_score': 0.7244084022999321,
#     'boxplot': {'min': 0.0996198945121428,
#      'q1': 0.69358285330433,
#      'median': 0.7525290983055526,
#      'q3': 0.7873448415043276,
#      'max': 0.8189267069430521}},
#    'A8': {'average_score': 0.5554787629861514,
#     'boxplot': {'min': 0.009179757131511358,
#      'q1': 0.5034076132350628,
#      'median': 0.5918613396759238,
#      'q3': 0.638898007287557,
#      'max': 0.7058997451681173}},
#    'R16': {'average_score': 0.7675055481700396,
#     'boxplot': {'min': 0.05022675472376184,
#      'q1': 0.7315429007537162,
#      'median': 0.7733308427106753,
#      'q3': 0.7965480433654862,
#      'max': 0.9535575234305393}},
#    'M2': {'average_score': 0.48654275130570807,
#     'boxplot': {'min': -0.021651236079367395,
#      'q1': 0.40252598745346346,
#      'median': 0.5138897697911592,
#      'q3': 0.6258139237103837,
#      'max': 0.692459192582354}},
#    'M4': {'average_score': 0.4577285337824104,
#     'boxplot': {'min': -0.09531248241809323,
#      'q1': 0.3631705367333117,
#      'median': 0.5127799614313591,
#      'q3': 0.5929955805334561,
#      'max': 0.6880215345508528}},
#    'M5': {'average_score': 0.761353878594219,
#     'boxplot': {'min': 0.04163509478940088,
#      'q1': 0.6881337529948437,
#      'median': 0.8022562026104896,
#      'q3': 0.8568147865569011,
#      'max': 0.8768856913429006}},
#    'R19': {'average_score': 0.9002242931256541,
#     'boxplot': {'min': 0.4945951693361878,
#      'q1': 0.8898327874736602,
#      'median': 0.9047588550587727,
#      'q3': 0.9332099023930075,
#      'max': 0.9535082243003659}}}},
#  'omnivore': {'average_score': 0.10454800562036315,
#   'boxplot': {'min': -0.7237228939233811,
#    'q1': -0.2082766709123817,
#    'median': 0.15914160168024294,
#    'q3': 0.44656841275993353,
#    'max': 0.6603949410994783},
#   'skills': {'M3': {'average_score': 0.6559624841415056,
#     'boxplot': {'min': -0.000642696233962881,
#      'q1': 0.6560180881213347,
#      'median': 0.7016000757153087,
#      'q3': 0.767068714486388,
#      'max': 0.8059533669959423}},
#    'M1': {'average_score': 0.7143539868731598,
#     'boxplot': {'min': 0.15133056383027552,
#      'q1': 0.6440443175999442,
#      'median': 0.7026601102969708,
#      'q3': 0.8163640579442714,
#      'max': 0.8924623444142176}},
#    'R18': {'average_score': 0.5346310626216615,
#     'boxplot': {'min': -0.02860073628701868,
#      'q1': 0.4555468185408491,
#      'median': 0.5923908168034362,
#      'q3': 0.6600871031025128,
#      'max': 0.7030593418846101}},
#    'A8': {'average_score': 0.5299037995408009,
#     'boxplot': {'min': 0.02722142851127772,
#      'q1': 0.4836752239830231,
#      'median': 0.5866393755361816,
#      'q3': 0.6318050911214237,
#      'max': 0.6818064926699245}},
#    'R16': {'average_score': 0.7865347028194786,
#     'boxplot': {'min': 0.510027965367798,
#      'q1': 0.7543275035060397,
#      'median': 0.7907341287446372,
#      'q3': 0.8199810449975774,
#      'max': 0.9350495737137924}},
#    'M2': {'average_score': 0.8371075680817712,
#     'boxplot': {'min': 0.1385877260680878,
#      'q1': 0.8580631451326869,
#      'median': 0.8725634499313802,
#      'q3': 0.8838283685782451,
#      'max': 0.9051340850574117}},
#    'M4': {'average_score': 0.5128561423693483,
#     'boxplot': {'min': -0.19407387947638063,
#      'q1': 0.3863018515291171,
#      'median': 0.5204558480825993,
#      'q3': 0.6800992098420824,
#      'max': 0.7724376028235516}},
#    'M5': {'average_score': 0.6963993225958115,
#     'boxplot': {'min': 0.3235101512616199,
#      'q1': 0.624513685222226,
#      'median': 0.7454241877755334,
#      'q3': 0.7933876339265216,
#      'max': 0.8102129632969572}},
#    'R19': {'average_score': 0.8200095804915114,
#     'boxplot': {'min': 0.1486105801557044,
#      'q1': 0.7981159820595084,
#      'median': 0.8287344755691319,
#      'q3': 0.8561294225938197,
#      'max': 0.9080871578650817}}}},
#  'avion': {'average_score': -0.04467407638871238,
#   'boxplot': {'min': -0.7222572040169406,
#    'q1': -0.20921885461158596,
#    'median': -0.059437666153743025,
#    'q3': 0.1103127428392909,
#    'max': 0.4720898411310116},
#   'skills': {'M3': {'average_score': 0.4643059369368555,
#     'boxplot': {'min': -0.022834147729464637,
#      'q1': 0.3792213163044943,
#      'median': 0.5211736277381999,
#      'q3': 0.6039626997666395,
#      'max': 0.6629436205848924}},
#    'M1': {'average_score': 0.613043918238867,
#     'boxplot': {'min': -0.014979382384612027,
#      'q1': 0.5641684344518103,
#      'median': 0.6452782982444234,
#      'q3': 0.6909207928090789,
#      'max': 0.774952431217709}},
#    'R18': {'average_score': 0.4104357602276142,
#     'boxplot': {'min': -0.012792863706720102,
#      'q1': 0.2697864560849015,
#      'median': 0.41048786072827914,
#      'q3': 0.5724088125096685,
#      'max': 0.6128754550559128}},
#    'A8': {'average_score': 0.611638086156237,
#     'boxplot': {'min': -0.01679448583958686,
#      'q1': 0.5776514654600222,
#      'median': 0.6577929712417793,
#      'q3': 0.7220143593920952,
#      'max': 0.7423058881518081}},
#    'R16': {'average_score': 0.521267598998223,
#     'boxplot': {'min': 0.012893388716003767,
#      'q1': 0.43201016719867735,
#      'median': 0.560146636621627,
#      'q3': 0.6547622534958857,
#      'max': 0.6932501204775313}},
#    'M2': {'average_score': 0.49188937087358003,
#     'boxplot': {'min': -0.04576962195112494,
#      'q1': 0.4080306556837375,
#      'median': 0.5455085630658957,
#      'q3': 0.6211333541409272,
#      'max': 0.6859528643974461}},
#    'M4': {'average_score': 0.4010089827675432,
#     'boxplot': {'min': -0.009241261370831502,
#      'q1': 0.2761457940027097,
#      'median': 0.46430202972072293,
#      'q3': 0.5373578534244084,
#      'max': 0.5945140428248136}},
#    'M5': {'average_score': 0.4822894818439662,
#     'boxplot': {'min': -0.017025416043334855,
#      'q1': 0.4072133313450841,
#      'median': 0.5261138695072924,
#      'q3': 0.6002225296893272,
#      'max': 0.6877265163350881}},
#    'R19': {'average_score': 0.4919327980171441,
#     'boxplot': {'min': 0.03307231462371768,
#      'q1': 0.41594012157602445,
#      'median': 0.5447446885606593,
#      'q3': 0.5858697920082302,
#      'max': 0.6496856023778173}}}}}

# %%
all_data
# Out:
# [{'id': 0,
#   'session_id': 0,
#   'frame_id': 1,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 85.23606872558594,
#   'y': -19.83711814880371,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 1,
#   'session_id': 1,
#   'frame_id': 18,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 72.09749603271484,
#   'y': -8.765467643737793,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 2,
#   'session_id': 2,
#   'frame_id': 17,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 72.88751220703125,
#   'y': -9.137545585632324,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 3,
#   'session_id': 3,
#   'frame_id': 81,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 71.74845123291016,
#   'y': -10.340615272521973,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 4,
#   'session_id': 4,
#   'frame_id': 111,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 74.16119384765625,
#   'y': -8.676165580749512,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 5,
#   'session_id': 5,
#   'frame_id': 115,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 71.58706665039062,
#   'y': -12.158623695373535,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 6,
#   'session_id': 6,
#   'frame_id': 179,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 72.57083892822266,
#   'y': -10.005270004272461,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 7,
#   'session_id': 7,
#   'frame_id': 179,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 71.81394958496094,
#   'y': -11.3283052444458,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 8,
#   'session_id': 8,
#   'frame_id': 220,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 75.136962890625,
#   'y': -8.309701919555664,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 9,
#   'session_id': 9,
#   'frame_id': 252,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 73.16935729980469,
#   'y': -8.937155723571777,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 10,
#   'session_id': 10,
#   'frame_id': 297,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 73.60950469970703,
#   'y': -9.618820190429688,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 11,
#   'session_id': 11,
#   'frame_id': 297,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 72.14714813232422,
#   'y': -10.113221168518066,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 12,
#   'session_id': 12,
#   'frame_id': 310,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 76.44435119628906,
#   'y': -7.0554704666137695,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 13,
#   'session_id': 13,
#   'frame_id': 367,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 72.11389923095703,
#   'y': -10.350253105163574,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 14,
#   'session_id': 14,
#   'frame_id': 403,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 72.97183227539062,
#   'y': -9.011211395263672,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 15,
#   'session_id': 15,
#   'frame_id': 403,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 71.82965850830078,
#   'y': -10.444953918457031,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 16,
#   'session_id': 16,
#   'frame_id': 462,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 76.70960998535156,
#   'y': -6.9156904220581055,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 17,
#   'session_id': 17,
#   'frame_id': 486,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 73.0668716430664,
#   'y': -10.207575798034668,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 18,
#   'session_id': 18,
#   'frame_id': 486,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 71.8905029296875,
#   'y': -11.13719367980957,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 19,
#   'session_id': 19,
#   'frame_id': 522,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 71.66090393066406,
#   'y': -12.975823402404785,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 20,
#   'session_id': 20,
#   'frame_id': 594,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 79.0248031616211,
#   'y': -13.989535331726074,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 21,
#   'session_id': 21,
#   'frame_id': 624,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 72.89730834960938,
#   'y': -12.030179977416992,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 22,
#   'session_id': 22,
#   'frame_id': 614,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 75.17127227783203,
#   'y': -11.384571075439453,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 23,
#   'session_id': 23,
#   'frame_id': 666,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 74.69583892822266,
#   'y': -11.925872802734375,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 24,
#   'session_id': 24,
#   'frame_id': 695,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 77.84771728515625,
#   'y': -8.715368270874023,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 25,
#   'session_id': 25,
#   'frame_id': 740,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 72.75431060791016,
#   'y': -11.133054733276367,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 26,
#   'session_id': 26,
#   'frame_id': 771,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 77.48885345458984,
#   'y': -7.353089332580566,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 27,
#   'session_id': 27,
#   'frame_id': 802,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 77.09481811523438,
#   'y': -7.907978057861328,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 28,
#   'session_id': 28,
#   'frame_id': 811,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 74.06389617919922,
#   'y': -12.452836036682129,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 29,
#   'session_id': 29,
#   'frame_id': 832,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 75.55744934082031,
#   'y': -14.267373085021973,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 30,
#   'session_id': 30,
#   'frame_id': 860,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 79.47219848632812,
#   'y': -12.699149131774902,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 31,
#   'session_id': 31,
#   'frame_id': 886,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 78.34698486328125,
#   'y': -12.54097843170166,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 32,
#   'session_id': 32,
#   'frame_id': 933,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 79.14137268066406,
#   'y': -9.592106819152832,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 33,
#   'session_id': 33,
#   'frame_id': 933,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 74.15495300292969,
#   'y': -12.953779220581055,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 34,
#   'session_id': 34,
#   'frame_id': 1014,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 79.68779754638672,
#   'y': -9.467499732971191,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 35,
#   'session_id': 35,
#   'frame_id': 1014,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 74.74571228027344,
#   'y': -12.59233570098877,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 36,
#   'session_id': 36,
#   'frame_id': 1073,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 78.6619873046875,
#   'y': -9.243627548217773,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 37,
#   'session_id': 37,
#   'frame_id': 1073,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 74.2155532836914,
#   'y': -13.11032772064209,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 38,
#   'session_id': 38,
#   'frame_id': 1107,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 78.92487335205078,
#   'y': -9.452986717224121,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 39,
#   'session_id': 39,
#   'frame_id': 1122,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 76.76829528808594,
#   'y': -13.239151954650879,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 40,
#   'session_id': 40,
#   'frame_id': 1148,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 75.57201385498047,
#   'y': -12.484050750732422,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 41,
#   'session_id': 41,
#   'frame_id': 1187,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 74.26506805419922,
#   'y': -13.494534492492676,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 42,
#   'session_id': 42,
#   'frame_id': 1246,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.69422912597656,
#   'y': -8.360502243041992,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 43,
#   'session_id': 43,
#   'frame_id': 1264,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 79.17543029785156,
#   'y': -8.215622901916504,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 44,
#   'session_id': 44,
#   'frame_id': 1290,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.07758331298828,
#   'y': -10.926056861877441,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 45,
#   'session_id': 45,
#   'frame_id': 1339,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 78.49478912353516,
#   'y': -13.788776397705078,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 46,
#   'session_id': 46,
#   'frame_id': 1339,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 79.26190948486328,
#   'y': -6.835142612457275,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 47,
#   'session_id': 47,
#   'frame_id': 1380,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 76.60818481445312,
#   'y': -13.257750511169434,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 48,
#   'session_id': 48,
#   'frame_id': 1438,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 79.2278823852539,
#   'y': -13.24321460723877,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 49,
#   'session_id': 49,
#   'frame_id': 1422,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 76.78353118896484,
#   'y': -9.650060653686523,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 50,
#   'session_id': 50,
#   'frame_id': 1471,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 81.35887145996094,
#   'y': -6.761030673980713,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 51,
#   'session_id': 51,
#   'frame_id': 1492,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 73.47179412841797,
#   'y': -12.547309875488281,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 52,
#   'session_id': 52,
#   'frame_id': 1552,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 78.85797882080078,
#   'y': -7.782713890075684,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 53,
#   'session_id': 53,
#   'frame_id': 1552,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 75.19934844970703,
#   'y': -11.239153861999512,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 54,
#   'session_id': 54,
#   'frame_id': 1580,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 77.40533447265625,
#   'y': -7.960854530334473,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 55,
#   'session_id': 55,
#   'frame_id': 1615,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 76.6597900390625,
#   'y': -8.880786895751953,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 56,
#   'session_id': 56,
#   'frame_id': 1636,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 75.3058853149414,
#   'y': -9.609931945800781,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 57,
#   'session_id': 57,
#   'frame_id': 1707,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 73.9005126953125,
#   'y': -11.882279396057129,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 58,
#   'session_id': 58,
#   'frame_id': 1713,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 76.60321044921875,
#   'y': -10.297856330871582,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 59,
#   'session_id': 59,
#   'frame_id': 1733,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 75.47916412353516,
#   'y': -11.946351051330566,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 60,
#   'session_id': 60,
#   'frame_id': 1746,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.65118408203125,
#   'y': -8.980779647827148,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 61,
#   'session_id': 61,
#   'frame_id': 1791,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 76.19043731689453,
#   'y': -12.080374717712402,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 62,
#   'session_id': 62,
#   'frame_id': 1858,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 81.5516586303711,
#   'y': -8.377277374267578,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 63,
#   'session_id': 63,
#   'frame_id': 1883,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 78.45830535888672,
#   'y': -11.923662185668945,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 64,
#   'session_id': 64,
#   'frame_id': 1883,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 81.58924102783203,
#   'y': -7.511524200439453,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 65,
#   'session_id': 65,
#   'frame_id': 1919,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 79.2823715209961,
#   'y': -10.722521781921387,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 66,
#   'session_id': 66,
#   'frame_id': 1936,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 76.88914489746094,
#   'y': -14.154970169067383,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 67,
#   'session_id': 67,
#   'frame_id': 2002,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 77.80493927001953,
#   'y': -13.563565254211426,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 68,
#   'session_id': 68,
#   'frame_id': 2019,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 79.1226577758789,
#   'y': -11.536482810974121,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 69,
#   'session_id': 69,
#   'frame_id': 2062,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 76.53286743164062,
#   'y': -13.030780792236328,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 70,
#   'session_id': 70,
#   'frame_id': 2056,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 78.35103607177734,
#   'y': -7.6793999671936035,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 71,
#   'session_id': 71,
#   'frame_id': 2106,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 73.73404693603516,
#   'y': -11.033782005310059,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 72,
#   'session_id': 72,
#   'frame_id': 2146,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 73.52115631103516,
#   'y': -13.894547462463379,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 73,
#   'session_id': 73,
#   'frame_id': 2145,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 77.66001892089844,
#   'y': -13.149404525756836,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 74,
#   'session_id': 74,
#   'frame_id': 2175,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.4825668334961,
#   'y': -12.300739288330078,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 75,
#   'session_id': 75,
#   'frame_id': 2226,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 73.20101165771484,
#   'y': -11.868768692016602,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 76,
#   'session_id': 76,
#   'frame_id': 2272,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 81.4888916015625,
#   'y': -8.069828987121582,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 77,
#   'session_id': 77,
#   'frame_id': 2291,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 78.6067123413086,
#   'y': -10.58358097076416,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 78,
#   'session_id': 78,
#   'frame_id': 2296,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.10285949707031,
#   'y': -8.971260070800781,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 79,
#   'session_id': 79,
#   'frame_id': 2327,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 78.32794952392578,
#   'y': -10.290392875671387,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 80,
#   'session_id': 80,
#   'frame_id': 2342,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.06011199951172,
#   'y': -9.426630973815918,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 81,
#   'session_id': 81,
#   'frame_id': 2424,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 77.67300415039062,
#   'y': -10.541706085205078,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 82,
#   'session_id': 82,
#   'frame_id': 2447,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.39031982421875,
#   'y': -7.500736236572266,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 83,
#   'session_id': 83,
#   'frame_id': 2455,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 75.39897155761719,
#   'y': -9.069918632507324,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 84,
#   'session_id': 84,
#   'frame_id': 2482,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 76.64763641357422,
#   'y': -15.451580047607422,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 85,
#   'session_id': 85,
#   'frame_id': 2531,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 76.09535217285156,
#   'y': -15.541895866394043,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 86,
#   'session_id': 86,
#   'frame_id': 2549,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 79.27031707763672,
#   'y': -12.714515686035156,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 87,
#   'session_id': 87,
#   'frame_id': 2586,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 78.08775329589844,
#   'y': -14.127673149108887,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 88,
#   'session_id': 88,
#   'frame_id': 2627,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 81.4471206665039,
#   'y': -6.983636379241943,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 89,
#   'session_id': 89,
#   'frame_id': 2627,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 76.29997253417969,
#   'y': -15.462872505187988,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 90,
#   'session_id': 90,
#   'frame_id': 2697,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 78.03247833251953,
#   'y': -12.39876651763916,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 91,
#   'session_id': 91,
#   'frame_id': 2697,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 75.13189697265625,
#   'y': -15.832473754882812,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 92,
#   'session_id': 92,
#   'frame_id': 2756,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 75.52193450927734,
#   'y': -15.719685554504395,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 93,
#   'session_id': 93,
#   'frame_id': 2782,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 74.43447875976562,
#   'y': -11.633298873901367,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 94,
#   'session_id': 94,
#   'frame_id': 2812,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 81.24275970458984,
#   'y': -9.110529899597168,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 95,
#   'session_id': 95,
#   'frame_id': 2803,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 78.71984100341797,
#   'y': -12.058852195739746,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 96,
#   'session_id': 96,
#   'frame_id': 2850,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.64814758300781,
#   'y': -9.733919143676758,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 97,
#   'session_id': 97,
#   'frame_id': 2890,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.62324523925781,
#   'y': -10.200321197509766,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 98,
#   'session_id': 98,
#   'frame_id': 2939,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 81.20648193359375,
#   'y': -10.502588272094727,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 99,
#   'session_id': 99,
#   'frame_id': 2924,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.09837341308594,
#   'y': -10.752148628234863,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 100,
#   'session_id': 100,
#   'frame_id': 2957,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.95060729980469,
#   'y': -7.8242316246032715,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 101,
#   'session_id': 101,
#   'frame_id': 2999,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 78.3917465209961,
#   'y': -9.963650703430176,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 102,
#   'session_id': 102,
#   'frame_id': 3053,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.26139831542969,
#   'y': -8.061850547790527,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 103,
#   'session_id': 103,
#   'frame_id': 3090,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 76.59310150146484,
#   'y': -12.073352813720703,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 104,
#   'session_id': 104,
#   'frame_id': 3078,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.23527526855469,
#   'y': -11.259832382202148,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 105,
#   'session_id': 105,
#   'frame_id': 3101,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 79.47154235839844,
#   'y': -11.577202796936035,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 106,
#   'session_id': 106,
#   'frame_id': 3139,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 81.1750717163086,
#   'y': -10.314908027648926,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 107,
#   'session_id': 107,
#   'frame_id': 3171,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 77.12841796875,
#   'y': -11.684646606445312,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 108,
#   'session_id': 108,
#   'frame_id': 3202,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 79.96711730957031,
#   'y': -10.28802490234375,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 109,
#   'session_id': 109,
#   'frame_id': 3244,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 77.04534912109375,
#   'y': -11.862044334411621,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 110,
#   'session_id': 110,
#   'frame_id': 3271,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 82.04923248291016,
#   'y': -7.781111717224121,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 111,
#   'session_id': 111,
#   'frame_id': 3291,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 74.64639282226562,
#   'y': -13.316143989562988,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 112,
#   'session_id': 112,
#   'frame_id': 3342,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 79.63850402832031,
#   'y': -10.674311637878418,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 113,
#   'session_id': 113,
#   'frame_id': 3389,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.8135986328125,
#   'y': -9.241090774536133,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 114,
#   'session_id': 114,
#   'frame_id': 3414,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 79.84466552734375,
#   'y': -8.85421371459961,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 115,
#   'session_id': 115,
#   'frame_id': 3414,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 74.29448699951172,
#   'y': -12.313024520874023,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 116,
#   'session_id': 116,
#   'frame_id': 3447,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 72.04158782958984,
#   'y': -14.227860450744629,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 117,
#   'session_id': 117,
#   'frame_id': 3452,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 73.44976043701172,
#   'y': -16.75566291809082,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 118,
#   'session_id': 118,
#   'frame_id': 3522,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 74.0149917602539,
#   'y': -17.105947494506836,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 119,
#   'session_id': 119,
#   'frame_id': 3566,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 74.23167419433594,
#   'y': -17.120624542236328,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 120,
#   'session_id': 120,
#   'frame_id': 3566,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 74.26847076416016,
#   'y': -16.844585418701172,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 121,
#   'session_id': 121,
#   'frame_id': 3620,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 74.40251159667969,
#   'y': -16.589330673217773,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 122,
#   'session_id': 122,
#   'frame_id': 3620,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 82.4137191772461,
#   'y': -23.93305206298828,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 123,
#   'session_id': 123,
#   'frame_id': 3661,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.61226654052734,
#   'y': -25.027978897094727,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 124,
#   'session_id': 124,
#   'frame_id': 3711,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 83.77622985839844,
#   'y': -22.447147369384766,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 125,
#   'session_id': 125,
#   'frame_id': 3711,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.37323760986328,
#   'y': -23.71338653564453,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 126,
#   'session_id': 126,
#   'frame_id': 3760,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 83.38231658935547,
#   'y': -23.129863739013672,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 127,
#   'session_id': 127,
#   'frame_id': 3807,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 81.44310760498047,
#   'y': -23.118274688720703,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 128,
#   'session_id': 128,
#   'frame_id': 3808,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 84.12068176269531,
#   'y': -22.75969123840332,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 129,
#   'session_id': 129,
#   'frame_id': 3832,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 82.83051300048828,
#   'y': -22.621997833251953,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 130,
#   'session_id': 130,
#   'frame_id': 3856,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 82.45918273925781,
#   'y': -22.330514907836914,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 131,
#   'session_id': 131,
#   'frame_id': 3917,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 81.28673553466797,
#   'y': -23.256614685058594,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 132,
#   'session_id': 132,
#   'frame_id': 3917,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 81.74652099609375,
#   'y': -22.92274284362793,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 133,
#   'session_id': 133,
#   'frame_id': 3956,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 81.69998168945312,
#   'y': -23.865882873535156,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 134,
#   'session_id': 134,
#   'frame_id': 4004,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 84.01451110839844,
#   'y': -22.51185417175293,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 135,
#   'session_id': 135,
#   'frame_id': 4015,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.62130737304688,
#   'y': -23.440793991088867,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 136,
#   'session_id': 136,
#   'frame_id': 4056,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.95692443847656,
#   'y': -22.821699142456055,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 137,
#   'session_id': 137,
#   'frame_id': 4080,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.60525512695312,
#   'y': -22.715539932250977,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 138,
#   'session_id': 138,
#   'frame_id': 4116,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 83.15596008300781,
#   'y': -21.977991104125977,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 139,
#   'session_id': 139,
#   'frame_id': 4161,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 82.09691619873047,
#   'y': -23.251834869384766,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 140,
#   'session_id': 140,
#   'frame_id': 4179,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 84.02384948730469,
#   'y': -22.486635208129883,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 141,
#   'session_id': 141,
#   'frame_id': 4182,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 82.17809295654297,
#   'y': -23.38540267944336,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 142,
#   'session_id': 142,
#   'frame_id': 4228,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 82.17325592041016,
#   'y': -23.43596649169922,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 143,
#   'session_id': 143,
#   'frame_id': 4263,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 83.0113525390625,
#   'y': -22.82964324951172,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 144,
#   'session_id': 144,
#   'frame_id': 4318,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 83.83623504638672,
#   'y': -22.88730239868164,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 145,
#   'session_id': 145,
#   'frame_id': 4318,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.68331146240234,
#   'y': -22.937711715698242,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 146,
#   'session_id': 146,
#   'frame_id': 4349,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 83.78858184814453,
#   'y': -22.788469314575195,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 147,
#   'session_id': 147,
#   'frame_id': 4403,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 82.37054443359375,
#   'y': -22.47593116760254,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 148,
#   'session_id': 148,
#   'frame_id': 4440,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 84.0018081665039,
#   'y': -21.736480712890625,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 149,
#   'session_id': 149,
#   'frame_id': 4423,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 84.75457763671875,
#   'y': -21.869287490844727,
#   'method': 'omnivore',
#   'session': 'M1-4',
#   'skill': 'M1'},
#  {'id': 150,
#   'session_id': 0,
#   'frame_id': 1,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 85.17862701416016,
#   'y': -20.102752685546875,
#   'method': 'omnivore',
#   'session': 'M1-3',
#   'skill': 'M1'},
#  {'id': 151,
#   'session_id': 1,
#   'frame_id': 21,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 81.41392517089844,
#   'y': -25.647462844848633,
#   'method': 'omnivore',
#   'session': 'M1-3',
#   'skill': 'M1'},
#  {'id': 152,
#   'session_id': 2,
#   'frame_id': 21,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 80.88188171386719,
#   'y': -26.75636100769043,
#   'method': 'omnivore',
#   'session': 'M1-3',
#   'skill': 'M1'},
#  {'id': 153,
#   'session_id': 3,
#   'frame_id': 59,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 83.27398681640625,
#   'y': -26.020008087158203,
#   'method': 'omnivore',
#   'session': 'M1-3',
#   'skill': 'M1'},
#  {'id': 154,
#   'session_id': 4,
#   'frame_id': 87,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 81.29940032958984,
#   'y': -26.54517364501953,
#   'method': 'omnivore',
#   'session': 'M1-3',
#   'skill': 'M1'},
#  {'id': 155,
#   'session_id': 5,
#   'frame_id': 118,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
#   'step_label_desc': 'No step',
#   'x': 79.97183990478516,
#   'y': -26.633398056030273,
#   'method': 'omnivore',
#   'session': 'M1-3',
#   'skill': 'M1'},
#  {'id': 156,
#   'session_id': 6,
#   'frame_id': 118,
#   'objects_class': array([], dtype=object),
#   'objects_conf': array([], dtype=object),
#   'step_label': 0,
# ...
#   'step_label': 3,
#   'step_label_desc': 'Push plunger firmly to deploy sponges into wound.',
#   'x': -5.352239608764648,
#   'y': -44.09368133544922,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 950,
#   'session_id': 17,
#   'frame_id': 494,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': -6.004591464996338,
#   'y': -43.88138961791992,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 951,
#   'session_id': 18,
#   'frame_id': 509,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': -4.158361434936523,
#   'y': -41.9478759765625,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 952,
#   'session_id': 19,
#   'frame_id': 531,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 0,
#   'step_label_desc': 'Open inner packaging and remove applicator.',
#   'x': -3.286306858062744,
#   'y': -31.53126335144043,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 953,
#   'session_id': 20,
#   'frame_id': 596,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': -3.45639967918396,
#   'y': -31.585174560546875,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 954,
#   'session_id': 21,
#   'frame_id': 612,
#   'objects_class': ['xstat_package'],
#   'objects_conf': array([0.41350585], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': -4.864884376525879,
#   'y': -32.69950485229492,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 955,
#   'session_id': 22,
#   'frame_id': 612,
#   'objects_class': ['xstat_package'],
#   'objects_conf': array([0.41350585], dtype=float32),
#   'step_label': 1,
#   'step_label_desc': 'Insert applicator into wound track as close to bleeding source as possible.',
#   'x': -4.583127498626709,
#   'y': -32.59587097167969,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 956,
#   'session_id': 23,
#   'frame_id': 663,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 1,
#   'step_label_desc': 'Insert applicator into wound track as close to bleeding source as possible.',
#   'x': -4.3691229820251465,
#   'y': -33.43955612182617,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 957,
#   'session_id': 24,
#   'frame_id': 696,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 2,
#   'step_label_desc': 'Insert plunger into applicator.',
#   'x': -3.188607692718506,
#   'y': -36.97843551635742,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 958,
#   'session_id': 25,
#   'frame_id': 696,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': -3.1264076232910156,
#   'y': -37.22774887084961,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 959,
#   'session_id': 26,
#   'frame_id': 744,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 3,
#   'step_label_desc': 'Push plunger firmly to deploy sponges into wound.',
#   'x': -4.449807643890381,
#   'y': -42.95772171020508,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 960,
#   'session_id': 27,
#   'frame_id': 786,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 3,
#   'step_label_desc': 'Push plunger firmly to deploy sponges into wound.',
#   'x': -5.605182647705078,
#   'y': -42.498756408691406,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 961,
#   'session_id': 28,
#   'frame_id': 807,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': -5.245507717132568,
#   'y': -42.31163787841797,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 962,
#   'session_id': 29,
#   'frame_id': 824,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': -2.9703240394592285,
#   'y': -40.50460433959961,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 963,
#   'session_id': 30,
#   'frame_id': 899,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': -8.05573844909668,
#   'y': -38.5209846496582,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 964,
#   'session_id': 31,
#   'frame_id': 902,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': -8.630974769592285,
#   'y': -38.57609558105469,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 965,
#   'session_id': 32,
#   'frame_id': 927,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': -8.752065658569336,
#   'y': -38.59931945800781,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 966,
#   'session_id': 33,
#   'frame_id': 983,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 4,
#   'step_label_desc': 'Apply manual pressure if necessary.',
#   'x': -9.489100456237793,
#   'y': -39.728271484375,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 967,
#   'session_id': 34,
#   'frame_id': 983,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 4,
#   'step_label_desc': 'Apply manual pressure if necessary.',
#   'x': -9.96766185760498,
#   'y': -39.47787857055664,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 968,
#   'session_id': 35,
#   'frame_id': 1019,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 4,
#   'step_label_desc': 'Apply manual pressure if necessary.',
#   'x': -9.010017395019531,
#   'y': -13.429221153259277,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 969,
#   'session_id': 36,
#   'frame_id': 1063,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 4,
#   'step_label_desc': 'Apply manual pressure if necessary.',
#   'x': -9.063783645629883,
#   'y': -12.91120719909668,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 970,
#   'session_id': 37,
#   'frame_id': 1092,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 4,
#   'step_label_desc': 'Apply manual pressure if necessary.',
#   'x': -9.143288612365723,
#   'y': -10.730539321899414,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 971,
#   'session_id': 38,
#   'frame_id': 1114,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 4,
#   'step_label_desc': 'Apply manual pressure if necessary.',
#   'x': -8.824687004089355,
#   'y': -9.135948181152344,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 972,
#   'session_id': 39,
#   'frame_id': 1136,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 4,
#   'step_label_desc': 'Apply manual pressure if necessary.',
#   'x': -8.840301513671875,
#   'y': -9.178472518920898,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 973,
#   'session_id': 40,
#   'frame_id': 1167,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': -6.878033638000488,
#   'y': -13.736459732055664,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 974,
#   'session_id': 41,
#   'frame_id': 1186,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': -5.688777446746826,
#   'y': -15.28531265258789,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 975,
#   'session_id': 42,
#   'frame_id': 1226,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': 7.870394229888916,
#   'y': -21.648487091064453,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 976,
#   'session_id': 43,
#   'frame_id': 1270,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': 8.925350189208984,
#   'y': -21.0308780670166,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 977,
#   'session_id': 44,
#   'frame_id': 1283,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': -1.6835724115371704,
#   'y': 15.590217590332031,
#   'method': 'omnivore',
#   'session': 'M5-4',
#   'skill': 'M5'},
#  {'id': 978,
#   'session_id': 0,
#   'frame_id': 1,
#   'objects_class': ['xstat_package',
#    'xstat_package',
#    'xstat_package',
#    'xstat_package'],
#   'objects_conf': array([0.45886487, 0.36899883, 0.3504431 , 0.34095615], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': 3.4930357933044434,
#   'y': -5.624908447265625,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 979,
#   'session_id': 1,
#   'frame_id': 17,
#   'objects_class': ['xstat_package',
#    'xstat_package',
#    'xstat_package',
#    'xstat_package'],
#   'objects_conf': array([0.45886487, 0.36899883, 0.3504431 , 0.34095615], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': 3.1435351371765137,
#   'y': -18.708906173706055,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 980,
#   'session_id': 2,
#   'frame_id': 26,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': 6.390947341918945,
#   'y': -18.476459503173828,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 981,
#   'session_id': 3,
#   'frame_id': 76,
#   'objects_class': ['xstat_package'],
#   'objects_conf': array([0.57317364], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': 6.160435676574707,
#   'y': -18.50192642211914,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 982,
#   'session_id': 4,
#   'frame_id': 96,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': 4.767503261566162,
#   'y': -19.48917579650879,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 983,
#   'session_id': 5,
#   'frame_id': 105,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': 4.211119651794434,
#   'y': -19.360889434814453,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 984,
#   'session_id': 6,
#   'frame_id': 143,
#   'objects_class': ['xstat_package'],
#   'objects_conf': array([0.31347847], dtype=float32),
#   'step_label': 1,
#   'step_label_desc': 'Insert applicator into wound track as close to bleeding source as possible.',
#   'x': 6.0031352043151855,
#   'y': -18.649497985839844,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 985,
#   'session_id': 7,
#   'frame_id': 186,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 1,
#   'step_label_desc': 'Insert applicator into wound track as close to bleeding source as possible.',
#   'x': 1.00310480594635,
#   'y': -41.82072830200195,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 986,
#   'session_id': 8,
#   'frame_id': 215,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 1,
#   'step_label_desc': 'Insert applicator into wound track as close to bleeding source as possible.',
#   'x': -1.2124345302581787,
#   'y': -41.41404342651367,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 987,
#   'session_id': 9,
#   'frame_id': 270,
#   'objects_class': ['xstat_applicator'],
#   'objects_conf': array([0.35090715], dtype=float32),
#   'step_label': 5,
#   'step_label_desc': 'No step',
#   'x': -1.4635149240493774,
#   'y': -41.664215087890625,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 988,
#   'session_id': 10,
#   'frame_id': 292,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 2,
#   'step_label_desc': 'Insert plunger into applicator.',
#   'x': -1.7560679912567139,
#   'y': -41.90243148803711,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 989,
#   'session_id': 11,
#   'frame_id': 287,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 2,
#   'step_label_desc': 'Insert plunger into applicator.',
#   'x': -1.653732180595398,
#   'y': -42.11672592163086,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 990,
#   'session_id': 12,
#   'frame_id': 340,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 2,
#   'step_label_desc': 'Insert plunger into applicator.',
#   'x': -1.5062892436981201,
#   'y': -42.285953521728516,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 991,
#   'session_id': 13,
#   'frame_id': 344,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 2,
#   'step_label_desc': 'Insert plunger into applicator.',
#   'x': -1.71346116065979,
#   'y': -42.11608123779297,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 992,
#   'session_id': 14,
#   'frame_id': 390,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 3,
#   'step_label_desc': 'Push plunger firmly to deploy sponges into wound.',
#   'x': -2.3536741733551025,
#   'y': -41.94921112060547,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 993,
#   'session_id': 15,
#   'frame_id': 427,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 3,
#   'step_label_desc': 'Push plunger firmly to deploy sponges into wound.',
#   'x': -2.656445264816284,
#   'y': -41.919456481933594,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 994,
#   'session_id': 16,
#   'frame_id': 426,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 3,
#   'step_label_desc': 'Push plunger firmly to deploy sponges into wound.',
#   'x': -2.7829082012176514,
#   'y': -41.921119689941406,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 995,
#   'session_id': 17,
#   'frame_id': 496,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 3,
#   'step_label_desc': 'Push plunger firmly to deploy sponges into wound.',
#   'x': -3.1886117458343506,
#   'y': -41.86713409423828,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 996,
#   'session_id': 18,
#   'frame_id': 499,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 4,
#   'step_label_desc': 'Apply manual pressure if necessary.',
#   'x': -2.8365023136138916,
#   'y': -41.101688385009766,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 997,
#   'session_id': 19,
#   'frame_id': 540,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 4,
#   'step_label_desc': 'Apply manual pressure if necessary.',
#   'x': -2.1457371711730957,
#   'y': -39.738800048828125,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 998,
#   'session_id': 20,
#   'frame_id': 599,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 4,
#   'step_label_desc': 'Apply manual pressure if necessary.',
#   'x': -8.160797119140625,
#   'y': -14.441621780395508,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  {'id': 999,
#   'session_id': 21,
#   'frame_id': 606,
#   'objects_class': [],
#   'objects_conf': array([], dtype=float32),
#   'step_label': 4,
#   'step_label_desc': 'Apply manual pressure if necessary.',
#   'x': -8.135815620422363,
#   'y': -13.049477577209473,
#   'method': 'omnivore',
#   'session': 'M5-5',
#   'skill': 'M5'},
#  ...]
