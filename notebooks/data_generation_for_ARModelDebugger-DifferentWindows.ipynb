# %% [markdown]
# ## Input data: Model outputs
# This data comes from scratch/XXXXXXX/Vis/output/
#
# It contains a folder for each skill (e.g., M2, M4, etc). Each folder contains multiple .npz files that represents the sessions. ``<video_id>``-features.npz files contain the features extracted from each video (session).
# Features contain the following keys: ``['fps', 'window_limit', 'omnivore', 'slowfast', 'avion', 'objects_conf', 'objects_bbox', 'hls_l_avg', 'window_medoid']``

# %% [markdown]
# ## Generate a reduced version of the data. Taking into account 10 sessions per skill

# %% [markdown]
# To extract all .npz file names from our manually created output folder and use them for the files_to_copy variable, the following Python script recursively search through the output folder, collect all .npz file names, and print or save them to a list.

# %%
import os

def extract_npz_files(source_dir):
    """
    Extracts all .npz file names from the source_dir and its subdirectories.
    
    :param source_dir: Path to the source directory containing all skills.
    :return: List of .npz file names.
    """
    npz_files = []
    
    for root, dirs, files in os.walk(source_dir):
        for file in files:
            if file.endswith('.npz'):
                # Store the relative path to maintain folder structure
                relative_path = os.path.relpath(os.path.join(root, file), source_dir)
                npz_files.append(relative_path)
    
    return npz_files

# Example usage
source_directory = '/Users/soniacq/PTG/BBN_data/updated_models/output_sample'  # Replace with your actual source directory
npz_files = extract_npz_files(source_directory)
print(npz_files)
# Print the list of .npz files
# for npz_file in npz_files:
#     print(npz_file)
# Out:
# ['M1/M1-4-features.npz', 'M1/M1-3-features.npz', 'M1/M1-2-features.npz', 'M1/M1-5-features.npz', 'M1/M1-8-features.npz', 'M1/assessment_2-features.npz', 'M1/assessment_1-features.npz', 'M1/M1-7-features.npz', 'M1/M1-1-features.npz', 'M1/M1-6-features.npz', 'M5/M5-8-features.npz', 'M5/20230712_100327_HoloLens-features.npz', 'M5/M5-3-features.npz', 'M5/M5-4-features.npz', 'M5/M5-5-features.npz', 'M5/M5-2-features.npz', 'M5/20230712_100156_HoloLens-features.npz', 'M5/M5-7-features.npz', 'M5/M5-6-features.npz', 'M5/M5-1-features.npz', 'R19/R19-5-features.npz', 'R19/R19-2-features.npz', 'R19/R19-10-features.npz', 'R19/R19-3-features.npz', 'R19/R19-4-features.npz', 'R19/R19-9-features.npz', 'R19/R19-8-features.npz', 'R19/R19-6-features.npz', 'R19/R19-1-features.npz', 'R19/R19-7-features.npz', 'M2/3_tourns_2-features.npz', 'M2/20230403_094350_HoloLens-features.npz', 'M2/M2-4-features.npz', 'M2/M2-3-features.npz', 'M2/M2-2-features.npz', 'M2/M2-5-features.npz', 'M2/20230403_094735_HoloLens-features.npz', 'M2/M2-1-features.npz', 'M2/M2-6-features.npz', 'M2/3_tourns_1-features.npz', 'M3/M3-5-features.npz', 'M3/M3-2-features.npz', 'M3/pressure_1-features.npz', 'M3/M3-3-features.npz', 'M3/M3-4-features.npz', 'M3/M3-6-features.npz', 'M3/M3-1-features.npz', 'M3/pressure_2-features.npz', 'M3/20240411_072951_HoloLens-features.npz', 'M3/20240411_073507_HoloLens-features.npz', 'R18/R18-4-features.npz', 'R18/R18-3-features.npz', 'R18/R18-2-features.npz', 'R18/R18-5-features.npz', 'R18/R18-8-features.npz', 'R18/seal_2-features.npz', 'R18/seal_1-features.npz', 'R18/R18-7-features.npz', 'R18/R18-1-features.npz', 'R18/R18-6-features.npz', 'A8/A8-7-features.npz', 'A8/A8-6-features.npz', 'A8/A8-1-features.npz', 'A8/A8-3-features.npz', 'A8/A8-4-features.npz', 'A8/A8-5-features.npz', 'A8/A8-2-features.npz', 'A8/A8-8-features.npz', 'A8/A8-10-features.npz', 'A8/A8-9-features.npz', 'M4/M4-9-features.npz', 'M4/M4-8-features.npz', 'M4/M4-2-features.npz', 'M4/M4-5-features.npz', 'M4/M4-4-features.npz', 'M4/M4-3-features.npz', 'M4/M4-1-features.npz', 'M4/M4-6-features.npz', 'M4/M4-10-features.npz', 'M4/M4-7-features.npz', 'R16/R16-10-features.npz', 'R16/R16-5-features.npz', 'R16/R16-2-features.npz', 'R16/R16-3-features.npz', 'R16/R16-4-features.npz', 'R16/R16-9-features.npz', 'R16/R16-8-features.npz', 'R16/R16-6-features.npz', 'R16/R16-1-features.npz', 'R16/R16-7-features.npz']

# %% [markdown]
# #### Generating reduced versions
# This script will maintain the folder structure and ensure that each .npz file is copied to the appropriate location in the target directory.

# %%
import os
import shutil

def copy_npz_files_with_structure(source_dir, target_dir, file_patterns):
    """
    Copy specific .npz files from source_dir to target_dir while preserving the directory structure.
    
    :param source_dir: Path to the source directory containing all skills.
    :param target_dir: Path to the target directory where files will be copied.
    :param file_patterns: List of file patterns to match (e.g., ['M1/M1-1-features.npz', 'M1/M1-2-features.npz']).
    """
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)

    for file_pattern in file_patterns:
        # Construct source and destination paths
        src_file = os.path.join(source_dir, file_pattern)
        if os.path.exists(src_file):
            # Create the target subdirectory if it doesn't exist
            target_file_path = os.path.join(target_dir, file_pattern)
            target_file_dir = os.path.dirname(target_file_path)
            if not os.path.exists(target_file_dir):
                os.makedirs(target_file_dir)
            
            # Copy the file
            shutil.copy(src_file, target_file_path)
            print(f'Copied {src_file} to {target_file_path}')
        else:
            print(f'File {src_file} does not exist.')

# Example usage
source_directory_window_1s = '/Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s'
target_directory_window_1s = '/Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample'
files_to_copy = npz_files  # Your list of npz files with paths

copy_npz_files_with_structure(source_directory_window_1s, target_directory_window_1s, files_to_copy)

# Example usage
source_directory_window_2s = '/Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s'
target_directory_window_2s = '/Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample'
files_to_copy = npz_files  # Your list of npz files with paths

copy_npz_files_with_structure(source_directory_window_2s, target_directory_window_2s, files_to_copy)

# Example usage
source_directory_window_4s = '/Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s'
target_directory_window_4s = '/Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample'
files_to_copy = npz_files  # Your list of npz files with paths

copy_npz_files_with_structure(source_directory_window_4s, target_directory_window_4s, files_to_copy)
# Out:
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M1/M1-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M1/M1-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M1/M1-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M1/M1-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M1/M1-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M1/M1-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M1/M1-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M1/M1-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M1/M1-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M1/M1-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M1/assessment_2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M1/assessment_2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M1/assessment_1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M1/assessment_1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M1/M1-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M1/M1-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M1/M1-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M1/M1-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M1/M1-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M1/M1-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M5/M5-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M5/M5-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M5/20230712_100327_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M5/20230712_100327_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M5/M5-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M5/M5-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M5/M5-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M5/M5-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M5/M5-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M5/M5-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M5/M5-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M5/M5-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M5/20230712_100156_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M5/20230712_100156_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M5/M5-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M5/M5-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M5/M5-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M5/M5-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M5/M5-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M5/M5-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R19/R19-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R19/R19-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R19/R19-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R19/R19-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R19/R19-10-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R19/R19-10-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R19/R19-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R19/R19-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R19/R19-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R19/R19-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R19/R19-9-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R19/R19-9-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R19/R19-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R19/R19-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R19/R19-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R19/R19-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R19/R19-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R19/R19-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R19/R19-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R19/R19-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M2/3_tourns_2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M2/3_tourns_2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M2/20230403_094350_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M2/20230403_094350_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M2/M2-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M2/M2-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M2/M2-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M2/M2-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M2/M2-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M2/M2-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M2/M2-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M2/M2-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M2/20230403_094735_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M2/20230403_094735_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M2/M2-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M2/M2-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M2/M2-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M2/M2-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M2/3_tourns_1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M2/3_tourns_1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M3/M3-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M3/M3-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M3/M3-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M3/M3-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M3/pressure_1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M3/pressure_1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M3/M3-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M3/M3-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M3/M3-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M3/M3-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M3/M3-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M3/M3-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M3/M3-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M3/M3-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M3/pressure_2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M3/pressure_2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M3/20240411_072951_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M3/20240411_072951_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M3/20240411_073507_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M3/20240411_073507_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R18/R18-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R18/R18-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R18/R18-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R18/R18-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R18/R18-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R18/R18-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R18/R18-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R18/R18-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R18/R18-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R18/R18-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R18/seal_2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R18/seal_2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R18/seal_1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R18/seal_1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R18/R18-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R18/R18-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R18/R18-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R18/R18-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R18/R18-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R18/R18-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/A8/A8-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/A8/A8-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/A8/A8-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/A8/A8-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/A8/A8-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/A8/A8-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/A8/A8-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/A8/A8-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/A8/A8-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/A8/A8-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/A8/A8-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/A8/A8-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/A8/A8-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/A8/A8-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/A8/A8-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/A8/A8-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/A8/A8-10-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/A8/A8-10-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/A8/A8-9-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/A8/A8-9-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M4/M4-9-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M4/M4-9-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M4/M4-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M4/M4-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M4/M4-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M4/M4-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M4/M4-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M4/M4-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M4/M4-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M4/M4-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M4/M4-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M4/M4-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M4/M4-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M4/M4-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M4/M4-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M4/M4-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M4/M4-10-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M4/M4-10-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/M4/M4-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/M4/M4-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R16/R16-10-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R16/R16-10-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R16/R16-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R16/R16-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R16/R16-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R16/R16-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R16/R16-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R16/R16-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R16/R16-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R16/R16-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R16/R16-9-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R16/R16-9-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R16/R16-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R16/R16-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R16/R16-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R16/R16-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R16/R16-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R16/R16-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s/R16/R16-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_1s_sample/R16/R16-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M1/M1-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M1/M1-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M1/M1-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M1/M1-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M1/M1-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M1/M1-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M1/M1-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M1/M1-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M1/M1-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M1/M1-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M1/assessment_2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M1/assessment_2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M1/assessment_1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M1/assessment_1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M1/M1-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M1/M1-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M1/M1-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M1/M1-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M1/M1-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M1/M1-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M5/M5-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M5/M5-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M5/20230712_100327_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M5/20230712_100327_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M5/M5-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M5/M5-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M5/M5-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M5/M5-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M5/M5-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M5/M5-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M5/M5-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M5/M5-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M5/20230712_100156_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M5/20230712_100156_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M5/M5-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M5/M5-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M5/M5-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M5/M5-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M5/M5-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M5/M5-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R19/R19-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R19/R19-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R19/R19-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R19/R19-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R19/R19-10-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R19/R19-10-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R19/R19-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R19/R19-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R19/R19-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R19/R19-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R19/R19-9-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R19/R19-9-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R19/R19-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R19/R19-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R19/R19-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R19/R19-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R19/R19-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R19/R19-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R19/R19-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R19/R19-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M2/3_tourns_2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M2/3_tourns_2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M2/20230403_094350_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M2/20230403_094350_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M2/M2-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M2/M2-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M2/M2-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M2/M2-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M2/M2-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M2/M2-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M2/M2-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M2/M2-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M2/20230403_094735_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M2/20230403_094735_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M2/M2-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M2/M2-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M2/M2-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M2/M2-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M2/3_tourns_1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M2/3_tourns_1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M3/M3-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M3/M3-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M3/M3-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M3/M3-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M3/pressure_1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M3/pressure_1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M3/M3-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M3/M3-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M3/M3-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M3/M3-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M3/M3-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M3/M3-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M3/M3-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M3/M3-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M3/pressure_2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M3/pressure_2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M3/20240411_072951_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M3/20240411_072951_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M3/20240411_073507_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M3/20240411_073507_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R18/R18-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R18/R18-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R18/R18-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R18/R18-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R18/R18-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R18/R18-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R18/R18-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R18/R18-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R18/R18-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R18/R18-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R18/seal_2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R18/seal_2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R18/seal_1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R18/seal_1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R18/R18-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R18/R18-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R18/R18-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R18/R18-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R18/R18-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R18/R18-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/A8/A8-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/A8/A8-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/A8/A8-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/A8/A8-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/A8/A8-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/A8/A8-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/A8/A8-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/A8/A8-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/A8/A8-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/A8/A8-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/A8/A8-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/A8/A8-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/A8/A8-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/A8/A8-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/A8/A8-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/A8/A8-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/A8/A8-10-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/A8/A8-10-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/A8/A8-9-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/A8/A8-9-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M4/M4-9-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M4/M4-9-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M4/M4-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M4/M4-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M4/M4-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M4/M4-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M4/M4-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M4/M4-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M4/M4-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M4/M4-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M4/M4-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M4/M4-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M4/M4-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M4/M4-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M4/M4-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M4/M4-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M4/M4-10-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M4/M4-10-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/M4/M4-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/M4/M4-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R16/R16-10-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R16/R16-10-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R16/R16-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R16/R16-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R16/R16-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R16/R16-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R16/R16-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R16/R16-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R16/R16-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R16/R16-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R16/R16-9-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R16/R16-9-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R16/R16-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R16/R16-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R16/R16-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R16/R16-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R16/R16-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R16/R16-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s/R16/R16-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_2s_sample/R16/R16-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M1/M1-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M1/M1-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M1/M1-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M1/M1-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M1/M1-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M1/M1-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M1/M1-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M1/M1-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M1/M1-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M1/M1-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M1/assessment_2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M1/assessment_2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M1/assessment_1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M1/assessment_1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M1/M1-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M1/M1-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M1/M1-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M1/M1-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M1/M1-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M1/M1-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M5/M5-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M5/M5-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M5/20230712_100327_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M5/20230712_100327_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M5/M5-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M5/M5-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M5/M5-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M5/M5-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M5/M5-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M5/M5-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M5/M5-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M5/M5-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M5/20230712_100156_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M5/20230712_100156_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M5/M5-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M5/M5-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M5/M5-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M5/M5-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M5/M5-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M5/M5-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R19/R19-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R19/R19-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R19/R19-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R19/R19-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R19/R19-10-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R19/R19-10-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R19/R19-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R19/R19-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R19/R19-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R19/R19-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R19/R19-9-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R19/R19-9-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R19/R19-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R19/R19-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R19/R19-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R19/R19-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R19/R19-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R19/R19-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R19/R19-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R19/R19-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M2/3_tourns_2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M2/3_tourns_2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M2/20230403_094350_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M2/20230403_094350_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M2/M2-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M2/M2-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M2/M2-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M2/M2-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M2/M2-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M2/M2-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M2/M2-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M2/M2-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M2/20230403_094735_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M2/20230403_094735_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M2/M2-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M2/M2-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M2/M2-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M2/M2-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M2/3_tourns_1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M2/3_tourns_1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M3/M3-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M3/M3-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M3/M3-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M3/M3-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M3/pressure_1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M3/pressure_1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M3/M3-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M3/M3-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M3/M3-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M3/M3-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M3/M3-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M3/M3-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M3/M3-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M3/M3-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M3/pressure_2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M3/pressure_2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M3/20240411_072951_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M3/20240411_072951_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M3/20240411_073507_HoloLens-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M3/20240411_073507_HoloLens-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R18/R18-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R18/R18-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R18/R18-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R18/R18-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R18/R18-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R18/R18-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R18/R18-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R18/R18-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R18/R18-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R18/R18-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R18/seal_2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R18/seal_2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R18/seal_1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R18/seal_1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R18/R18-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R18/R18-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R18/R18-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R18/R18-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R18/R18-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R18/R18-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/A8/A8-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/A8/A8-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/A8/A8-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/A8/A8-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/A8/A8-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/A8/A8-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/A8/A8-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/A8/A8-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/A8/A8-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/A8/A8-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/A8/A8-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/A8/A8-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/A8/A8-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/A8/A8-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/A8/A8-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/A8/A8-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/A8/A8-10-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/A8/A8-10-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/A8/A8-9-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/A8/A8-9-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M4/M4-9-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M4/M4-9-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M4/M4-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M4/M4-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M4/M4-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M4/M4-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M4/M4-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M4/M4-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M4/M4-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M4/M4-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M4/M4-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M4/M4-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M4/M4-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M4/M4-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M4/M4-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M4/M4-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M4/M4-10-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M4/M4-10-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/M4/M4-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/M4/M4-7-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R16/R16-10-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R16/R16-10-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R16/R16-5-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R16/R16-5-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R16/R16-2-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R16/R16-2-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R16/R16-3-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R16/R16-3-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R16/R16-4-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R16/R16-4-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R16/R16-9-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R16/R16-9-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R16/R16-8-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R16/R16-8-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R16/R16-6-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R16/R16-6-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R16/R16-1-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R16/R16-1-features.npz
# Copied /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s/R16/R16-7-features.npz to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/R16/R16-7-features.npz

# %% [markdown]
# ### Testing

# %%
import numpy as np
import math

user_path = target_directory_window_4s + "/R19/"
# scp -r scqXXX@greene.hpc.nyu.edu:/scratch/XXXXXXX/data/BBN/features/M2/aug_img_perc0.8_NEW-YOLO_weighted_loss .
path_original_data = user_path # + 'BBN_data/RNN/aug_img_perc0.8_NEW-YOLO_weighted_loss/'
# Load the .npy file with allow_pickle=True
features_M2_1 = np.load(path_original_data + 'R19-10-features.npz', allow_pickle=True)

# Load the .npy file with allow_pickle=True
# labels_M2_1 = np.load(path_original_data + '3_tourns_2-window_label.npz', allow_pickle=True)

# %%
# Get the keys and convert them to a list
keys = list(features_M2_1.keys())
# Print the keys
print(keys)
# # Get the keys and convert them to a list
# keys_labels = list(labels_M2_1.keys())
# # Print the keys
# print(keys_labels)
# Out:
# ['fps', 'window_limit', 'window_medoid', 'omnivore', 'slowfast', 'avion', 'objects_conf', 'objects_bbox', 'label', 'label_desc', 'hls_l_avg', 'objects_class']

# %% [markdown]
# We should have the following data (12 in total): ['fps', 'window_limit', 'omnivore', 'slowfast', 'avion', 'objects_conf', 'objects_bbox', 'hls_l_avg', 'window_medoid', 'objects_class', 'label', 'label_desc']

# %%
temp = ['No Step'] * features_M2_1['window_medoid'].shape[0] if features_M2_1['label'].shape[0] == 0 else features_M2_1['label']
max(np.unique(temp))
# Out:
# 6

# %%
features_M2_1['window_medoid']
# Out:
# array([   1,   27,   70,   72,  148,  274,  281,  403,  403,  471,  571,
#         607,  611,  738,  738,  826,  899,  952,  991, 1057, 1154, 1180,
#        1264])

# %%
omnivore_features = features_M2_1['omnivore']
print(features_M2_1['omnivore'].shape)
print(features_M2_1['slowfast'].shape)
print(features_M2_1['avion'].shape)

# array_labels = labels_M2_1['label_desc']
# print(len(array_labels))
# Out:
# (51, 1024)
# (51, 1600)
# (51, 3806)

# %%
window_limit_data = features_M2_1['window_limit']
n_window_frames = window_limit_data.shape[0]-1
last_IDframe = window_limit_data[n_window_frames][1]
video_duration = round(last_IDframe/features_M2_1['fps'].item()) # Use round() to round a number to the nearest integer
print("n_window_frames:", n_window_frames)
print("last_IDframe:", last_IDframe)
print("video_duration:", video_duration)
# Out:
# n_window_frames: 50
# last_IDframe: 1495
# video_duration: 50

# %%
window_limit_data.shape[0]
# Out:
# 51

# %% [markdown]
# # Data Generation

# %%
# path_raw_data = target_directory_window_1s
# path_raw_data = target_directory_window_2s
path_raw_data = target_directory_window_4s

# %% [markdown]
# ## Generate session metadata

# %%
import os
import numpy as np
import json

def compute_video_metadata(npz_file_path):
    features = np.load(npz_file_path, allow_pickle=True)
    window_limit_data = features['window_limit']
    n_window_frames = window_limit_data.shape[0] - 1
    last_IDframe = window_limit_data[n_window_frames][1]
    label = [0] * features['window_medoid'].shape[0] if features['label'].shape[0] == 0 else features['label']
    label_desc = ['No step'] * features['window_medoid'].shape[0] if features['label_desc'].shape[0] == 0 else features['label_desc']
    fps = features['fps'].item()
    duration_seconds = round(last_IDframe / fps)
    
    
    return {
        "duration_seconds": duration_seconds,
        "numberof_window_frames": n_window_frames,
        "last_IDframe": int(last_IDframe),
        "total_labels": int(len(np.unique(label))),
        "max_id_labels": int(max(np.unique(label))),
        "unique_labels": str(np.unique(label_desc)),
        "unique_id_labels": str(np.unique(label))
    }

def generate_json(directory):
    data = {}
    
    for skill_name in os.listdir(directory):
        skill_path = os.path.join(directory, skill_name)
        if os.path.isdir(skill_path):
            skill_data = {}
            for file_name in os.listdir(skill_path):
                if file_name.endswith('-features.npz'):
                    video_id = file_name.split('-features.npz')[0]
                    file_path = os.path.join(skill_path, file_name)
                    video_metadata = compute_video_metadata(file_path)
                    skill_data[video_id] = video_metadata
            if skill_data:
                data[skill_name] = skill_data

    return data

def save_json(data, output_file):
    with open(output_file, 'w') as json_file:
        json.dump(data, json_file, indent=4)

# Example usage in a Jupyter notebook
directory = path_raw_data  # Replace with the path to the directory containing the skill folders
output_file = path_raw_data + "/sessions_metadata.json"            # Replace with the desired output file path
result = generate_json(directory)
save_json(result, output_file)
print("JSON file generated successfully.")
# Out:
# JSON file generated successfully.

# %% [markdown]
# ## Generate data for each window_frame for each corresponging session

# %%
import os
import numpy as np
import json


def generate_detailed_json(directory):
    data = []
    
    for skill_name in os.listdir(directory):
        skill_path = os.path.join(directory, skill_name)
        if os.path.isdir(skill_path):
            for file_name in os.listdir(skill_path):
                if file_name.endswith('-features.npz'):
                    video_id = file_name.split('-features.npz')[0]
                    file_path = os.path.join(skill_path, file_name)
                    features = np.load(file_path, allow_pickle=True)
                    
                    keys = list(features.keys())
                    # Print the keys
                    hls_l_avg = features['hls_l_avg']
                    label = [0] * features['window_medoid'].shape[0] if features['label'].shape[0] == 0 else features['label']
                    label_desc = ['No step'] * features['window_medoid'].shape[0] if features['label_desc'].shape[0] == 0 else features['label_desc']
                    objects_bbox = features['objects_bbox']
                    objects_conf = features['objects_conf']
                    frame_id = features['window_medoid']
                    
                    trial_data = []
                    
                    for i in range(len(hls_l_avg)):
                        window_data = {
                            "seconds": i,
                            "hls_lightness_avg": float(hls_l_avg[i]),
                            "step": float(label[i]),
                            "step_desc": label_desc[i],
                            "objects_bbox": objects_bbox[i].tolist(),
                            "objects_conf": objects_conf[i].tolist(),
                            # "objects_conf_avg": float(np.mean(objects_conf[i]))
                            "objects_conf_avg": float(np.mean(objects_conf[i])) if len(objects_conf[i]) > 0 else -1,
                            "frame_id": str(frame_id[i])
                        }
                        trial_data.append(window_data)
                    
                    subject_data = {
                        "skill_id": skill_name,
                        "session_id": video_id,
                        "data": trial_data
                    }
                    
                    data.append(subject_data)
    
    return data

def save_json(data, output_file):
    with open(output_file, 'w') as json_file:
        json.dump(data, json_file, indent=4)

# Example usage in a Jupyter notebook
directory = path_raw_data  # Replace with the path to the directory containing the skill folders
output_file = path_raw_data + "/sessions_window_frame_data.json"            # Replace with the desired output file path
result = generate_detailed_json(directory)
save_json(result, output_file)
print("JSON file generated successfully.")
# Out:
# JSON file generated successfully.

# %% [markdown]
# ### Save t-SNE resutls

# %% [markdown]
# #### tsne position for all sessions,l using PCA, tSNE, and UMAP

# %%
import os
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap  # Import UMAP

def load_features(file_path):
    features = np.load(file_path, allow_pickle=True)
    omnivore = features['omnivore']
    slowfast = features['slowfast']
    avion = features['avion']
    window_medoid = features['window_medoid']
    objects_class = features['objects_class']
    objects_conf = features['objects_conf']
    step_label = [0] * features['window_medoid'].shape[0] if features['label'].shape[0] == 0 else features['label']
    step_label_desc = ['No step'] * features['window_medoid'].shape[0] if features['label_desc'].shape[0] == 0 else features['label_desc']
    
    return omnivore, slowfast, avion, window_medoid, objects_class, objects_conf, step_label, step_label_desc

def apply_pca(features, metadata):
    pca = PCA(n_components=2, random_state=42)
    pca_results = pca.fit_transform(features)
    return format_data(pca_results, metadata)

def apply_tsne(features, metadata):
    tsne = TSNE(n_components=2, random_state=42)
    tsne_results = tsne.fit_transform(features)
    return format_data(tsne_results, metadata)

def apply_umap(features, metadata):
    umap_model = umap.UMAP(n_components=2, random_state=42)
    umap_results = umap_model.fit_transform(features)
    return format_data(umap_results, metadata)

def format_data(results, metadata):
    data = []
    for i, (x, y) in enumerate(results):
        data.append({
            "id": metadata[i]['id'],
            "session_id": metadata[i]['session_id'],
            "frame_id": metadata[i]['frame_id'],
            "objects_class": metadata[i]['objects_class'],
            "objects_conf": metadata[i]['objects_conf'],
            "step_label": metadata[i]['step_label'],
            "step_label_desc": metadata[i]['step_label_desc'],
            "x": float(x),  # Convert to native Python float
            "y": float(y),  # Convert to native Python float
            "method": metadata[i]['method'],
            "session": metadata[i]['session'],
            "skill": metadata[i]['skill']
        })
    return data

def generate_csv(directory, pca_output_file, tsne_output_file, umap_output_file):
    all_omnivore_features = []
    all_slowfast_features = []
    all_avion_features = []
    
    omnivore_labels = []
    slowfast_labels = []
    avion_labels = []
    
    for skill_name in os.listdir(directory):
        skill_path = os.path.join(directory, skill_name)
        if os.path.isdir(skill_path):
            for file_name in os.listdir(skill_path):
                if file_name.endswith('-features.npz'):
                    video_id = file_name.split('-features.npz')[0]
                    file_path = os.path.join(skill_path, file_name)
                    omnivore, slowfast, avion, window_medoid, objects_class, objects_conf, step_label, step_label_desc = load_features(file_path)
                    
                    session_length = len(omnivore) + len(slowfast) + len(avion)
                    current_session_id = 0
                    for i in range(len(omnivore)):
                        omnivore_labels.append({"id": len(omnivore_labels), "session_id": current_session_id, "frame_id": window_medoid[i], "objects_class": objects_class[i], "objects_conf": objects_conf[i], "step_label": step_label[i], "step_label_desc": step_label_desc[i], "method": 'omnivore', "session": video_id, "skill": skill_name})
                        current_session_id += 1
                    current_session_id = 0
                    for i in range(len(slowfast)):
                        slowfast_labels.append({"id": len(slowfast_labels), "session_id": current_session_id, "frame_id": window_medoid[i], "objects_class": objects_class[i], "objects_conf": objects_conf[i], "step_label": step_label[i], "step_label_desc": step_label_desc[i], "method": 'slowfast', "session": video_id, "skill": skill_name})
                        current_session_id += 1
                    current_session_id = 0
                    for i in range(len(avion)):
                        avion_labels.append({"id": len(avion_labels), "session_id": current_session_id, "frame_id": window_medoid[i], "objects_class": objects_class[i], "objects_conf": objects_conf[i], "step_label": step_label[i], "step_label_desc": step_label_desc[i], "method": 'avion', "session": video_id, "skill": skill_name})
                        current_session_id += 1
                    
                    all_omnivore_features.append(omnivore)
                    all_slowfast_features.append(slowfast)
                    all_avion_features.append(avion)
    
    # Concatenate all features
    all_omnivore_features = np.concatenate(all_omnivore_features)
    all_slowfast_features = np.concatenate(all_slowfast_features)
    all_avion_features = np.concatenate(all_avion_features)
    
    # Apply PCA, t-SNE, and UMAP on the concatenated features
    omnivore_pca_data = apply_pca(all_omnivore_features, omnivore_labels)
    slowfast_pca_data = apply_pca(all_slowfast_features, slowfast_labels)
    avion_pca_data = apply_pca(all_avion_features, avion_labels)
    
    omnivore_tsne_data = apply_tsne(all_omnivore_features, omnivore_labels)
    slowfast_tsne_data = apply_tsne(all_slowfast_features, slowfast_labels)
    avion_tsne_data = apply_tsne(all_avion_features, avion_labels)
    
    omnivore_umap_data = apply_umap(all_omnivore_features, omnivore_labels)
    slowfast_umap_data = apply_umap(all_slowfast_features, slowfast_labels)
    avion_umap_data = apply_umap(all_avion_features, avion_labels)
    
    # Combine all PCA data
    all_pca_data = omnivore_pca_data + slowfast_pca_data + avion_pca_data
    
    # Combine all t-SNE data
    all_tsne_data = omnivore_tsne_data + slowfast_tsne_data + avion_tsne_data
    
    # Combine all UMAP data
    all_umap_data = omnivore_umap_data + slowfast_umap_data + avion_umap_data
    
    # Save to CSV
    pca_df = pd.DataFrame(all_pca_data)
    pca_df.to_csv(pca_output_file, index=False)
    print(f"PCA CSV file generated successfully: {pca_output_file}")
    
    tsne_df = pd.DataFrame(all_tsne_data)
    tsne_df.to_csv(tsne_output_file, index=False)
    print(f"t-SNE CSV file generated successfully: {tsne_output_file}")
    
    umap_df = pd.DataFrame(all_umap_data)
    umap_df.to_csv(umap_output_file, index=False)
    print(f"UMAP CSV file generated successfully: {umap_output_file}")
    
    return all_pca_data, all_tsne_data, all_umap_data

# Example usage in a Jupyter notebook
directory = path_raw_data  # Replace with the path to the directory containing the skill folders
pca_output_file = os.path.join(directory, "all_sessions_pca_results_10p.csv")
tsne_output_file = os.path.join(directory, "all_sessions_tsne_results_10p.csv")
umap_output_file = os.path.join(directory, "all_sessions_umap_results_10p.csv")
all_pca_data, all_tsne_data, all_umap_data = generate_csv(directory, pca_output_file, tsne_output_file, umap_output_file)
# Out:
# /opt/miniconda3/envs/bbn/lib/python3.12/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /opt/miniconda3/envs/bbn/lib/python3.12/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /opt/miniconda3/envs/bbn/lib/python3.12/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# PCA CSV file generated successfully: /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/all_sessions_pca_results_10p.csv
# t-SNE CSV file generated successfully: /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/all_sessions_tsne_results_10p.csv
# UMAP CSV file generated successfully: /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/output/window_4s_sample/all_sessions_umap_results_10p.csv

# %% [markdown]
# ## Compute Similarity scores

# %% [markdown]
# #### Using kmeans (2 clusters) to calculate silhouette score for each skill (individual class)

# %%
import numpy as np
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.cluster import KMeans
import json

def compute_silhouette_scores(data):
    print("Hello")
    # Initialize results dictionary
    results = {}
    
    # Get unique methods
    methods = set(d['method'] for d in data)
    
    for method in methods:
        # Filter data based on the method
        method_data = [d for d in data if d['method'] == method]
        
        # Extract x, y positions and skill labels
        positions = np.array([(d['x'], d['y']) for d in method_data])
        labels = np.array([d['skill'] for d in method_data])
        print(labels)
        # Ensure there are at least two unique labels
        if len(set(labels)) > 1:
            # Compute overall silhouette score and boxplot statistics
            silhouette_values = silhouette_samples(positions, labels, metric='euclidean')
            average_score = silhouette_score(positions, labels, metric='euclidean')
            boxplot_stats = calculate_boxplot_stats(silhouette_values)
            
            # Initialize method results
            method_results = {
                'average_score': average_score,
                'boxplot': boxplot_stats,
                'skills': {}
            }
            
            # Calculate silhouette score for each skill (individual class)
            skills = set(labels)
            for skill in skills:
                # Filter data for the specific skill
                skill_data = np.array([pos for pos, lbl in zip(positions, labels) if lbl == skill])
                
                # Apply KMeans clustering to get cluster labels for skill data
                if len(skill_data) > 1:
                    kmeans = KMeans(n_clusters=2, random_state=0).fit(skill_data)
                    skill_labels = kmeans.labels_
                    
                    # Compute silhouette score for skill data
                    skill_silhouette_values = silhouette_samples(skill_data, skill_labels, metric='euclidean')
                    skill_average_score = silhouette_score(skill_data, skill_labels, metric='euclidean')
                    skill_boxplot_stats = calculate_boxplot_stats(skill_silhouette_values)
                    
                    # Store skill results
                    method_results['skills'][skill] = {
                        'average_score': skill_average_score,
                        'boxplot': skill_boxplot_stats
                    }
            
            # Store method results in the main results dictionary
            results[method] = method_results
    
    # Save results to a JSON file
    silhoutte_path = path_raw_data + "/silhouette_scores.json"
    with open(silhoutte_path, 'w') as outfile:
        json.dump(results, outfile, indent=4)
    
    return results

def calculate_boxplot_stats(data):
    # Sort data
    sorted_data = np.sort(data)
    
    # Calculate quartiles
    q1 = np.percentile(sorted_data, 25)
    median = np.percentile(sorted_data, 50)
    q3 = np.percentile(sorted_data, 75)
    min_value = sorted_data[0]
    max_value = sorted_data[-1]
    
    return {
        'min': min_value,
        'q1': q1,
        'median': median,
        'q3': q3,
        'max': max_value
    }

# Compute silhouette scores and save to JSON
results = compute_silhouette_scores(all_data)

results
# Out:
# Hello
# ['M1' 'M1' 'M1' ... 'R16' 'R16' 'R16']
# ['M1' 'M1' 'M1' ... 'R16' 'R16' 'R16']
# ['M1' 'M1' 'M1' ... 'R16' 'R16' 'R16']
# {'omnivore': {'average_score': 0.11586185767699353,
#   'boxplot': {'min': -0.7089620427280873,
#    'q1': -0.18062965983748563,
#    'median': 0.16584202113233062,
#    'q3': 0.45000095982587845,
#    'max': 0.6578222000579298},
#   'skills': {'M5': {'average_score': 0.7183624096198824,
#     'boxplot': {'min': 0.1808708342673149,
#      'q1': 0.652535803013684,
#      'median': 0.7806542520518555,
#      'q3': 0.8085438433133809,
#      'max': 0.8496638791762264}},
#    'M2': {'average_score': 0.8524349428474006,
#     'boxplot': {'min': 0.07206482223398054,
#      'q1': 0.8662045823149115,
#      'median': 0.8803178960688576,
#      'q3': 0.8936254411955391,
#      'max': 0.9189645979096883}},
#    'R16': {'average_score': 0.8191038524435319,
#     'boxplot': {'min': 0.6505884331575554,
#      'q1': 0.7920248275323194,
#      'median': 0.8275653362709775,
#      'q3': 0.8499536880385701,
#      'max': 0.910048818677284}},
#    'M1': {'average_score': 0.7273887179438435,
#     'boxplot': {'min': 0.29954747558489037,
#      'q1': 0.6592475478000769,
#      'median': 0.6944788787997611,
#      'q3': 0.7853192384869823,
#      'max': 0.9179198849681792}},
#    'M4': {'average_score': 0.4532202122289543,
#     'boxplot': {'min': -0.16864134083316723,
#      'q1': 0.40834356977834757,
#      'median': 0.4773775107754877,
#      'q3': 0.5337492371614099,
#      'max': 0.7886081517128847}},
#    'M3': {'average_score': 0.6284871790130823,
#     'boxplot': {'min': 0.004108367598208668,
#      'q1': 0.5975289260909067,
#      'median': 0.7073291416361391,
#      'q3': 0.7760708254927027,
#      'max': 0.8087141787810362}},
#    'R18': {'average_score': 0.6309339465523797,
#     'boxplot': {'min': 0.273359917895438,
#      'q1': 0.5086598754322518,
#      'median': 0.7076744325351487,
#      'q3': 0.744010437544292,
#      'max': 0.7820989713728767}},
#    'A8': {'average_score': 0.51656796048374,
#     'boxplot': {'min': -0.1896721584814838,
#      'q1': 0.42743434319110574,
#      'median': 0.5617334837630864,
#      'q3': 0.6618188806931002,
#      'max': 0.7217430752550816}},
#    'R19': {'average_score': 0.802432136326712,
#     'boxplot': {'min': 0.4636574507495128,
#      'q1': 0.7607612183267042,
#      'median': 0.8075676295487637,
#      'q3': 0.8609257319091979,
#      'max': 0.9157536529707438}}}},
#  'slowfast': {'average_score': 0.16380980516253874,
#   'boxplot': {'min': -0.744887580015702,
#    'q1': -0.16710591829298682,
#    'median': 0.277721822354953,
#    'q3': 0.5294975988628303,
#    'max': 0.6728096766393569},
#   'skills': {'M5': {'average_score': 0.7547256035168318,
#     'boxplot': {'min': 0.02739413429066147,
#      'q1': 0.6981885712933807,
#      'median': 0.7944115367134672,
#      'q3': 0.8611128613388621,
#      'max': 0.8760567490807486}},
#    'M2': {'average_score': 0.53328154460645,
#     'boxplot': {'min': -0.04526377047097271,
#      'q1': 0.4751483167113444,
#      'median': 0.5834236607461701,
#      'q3': 0.6517458854515612,
#      'max': 0.7011626516118102}},
#    'R16': {'average_score': 0.773591589204004,
#     'boxplot': {'min': 0.37081777441054303,
#      'q1': 0.7514873639032328,
#      'median': 0.7801535389913632,
#      'q3': 0.8051921029315039,
#      'max': 0.9559182683420422}},
#    'M1': {'average_score': 0.42887358773906453,
#     'boxplot': {'min': -0.10649703010842629,
#      'q1': 0.30494018674359885,
#      'median': 0.4464420035945995,
#      'q3': 0.5815450226988079,
#      'max': 0.6705194950784519}},
#    'M4': {'average_score': 0.4663646016422702,
#     'boxplot': {'min': -0.11822340481562969,
#      'q1': 0.3461523170881312,
#      'median': 0.5251310357482191,
#      'q3': 0.6102627334561272,
#      'max': 0.7044542711897646}},
#    'M3': {'average_score': 0.6911364638139389,
#     'boxplot': {'min': 0.06061299558253587,
#      'q1': 0.6052059321048302,
#      'median': 0.7232703575429339,
#      'q3': 0.7974705976623702,
#      'max': 0.836326317685776}},
#    'R18': {'average_score': 0.7444127596061615,
#     'boxplot': {'min': -0.018490530172478304,
#      'q1': 0.7149812974596252,
#      'median': 0.7855877778765779,
#      'q3': 0.827845175525098,
#      'max': 0.8483313867274321}},
#    'A8': {'average_score': 0.519308344191084,
#     'boxplot': {'min': 0.09142399375634538,
#      'q1': 0.4536230416661517,
#      'median': 0.5596437607340076,
#      'q3': 0.6149873377063146,
#      'max': 0.667274396986859}},
#    'R19': {'average_score': 0.8981232923678367,
#     'boxplot': {'min': 0.5884310047401738,
#      'q1': 0.8913954484744827,
#      'median': 0.9041404156439832,
#      'q3': 0.9355802066049772,
#      'max': 0.9553881947281706}}}},
#  'avion': {'average_score': -0.054908110303017545,
#   'boxplot': {'min': -0.7232528551425251,
#    'q1': -0.24047682401236034,
#    'median': -0.07854269809536044,
#    'q3': 0.08429207846976598,
#    'max': 0.49179919881961753},
#   'skills': {'M5': {'average_score': 0.39648032862816707,
#     'boxplot': {'min': 0.011316466887839051,
#      'q1': 0.2802654616153655,
#      'median': 0.4225777644988109,
#      'q3': 0.5353862795427227,
#      'max': 0.6050516462346082}},
#    'M2': {'average_score': 0.468900254905708,
#     'boxplot': {'min': -0.11350756645034464,
#      'q1': 0.35993850311863795,
#      'median': 0.5218975679413954,
#      'q3': 0.6446931001434588,
#      'max': 0.707395411340075}},
#    'R16': {'average_score': 0.6271707495762268,
#     'boxplot': {'min': 0.025210346933789454,
#      'q1': 0.5793387004161014,
#      'median': 0.6853072709952934,
#      'q3': 0.7461614470303558,
#      'max': 0.7967731840130614}},
#    'M1': {'average_score': 0.6981075933447599,
#     'boxplot': {'min': 0.030264182255120335,
#      'q1': 0.6984012826416682,
#      'median': 0.7399133324285696,
#      'q3': 0.7631208675460935,
#      'max': 0.8250724874156102}},
#    'M4': {'average_score': 0.4280244547419257,
#     'boxplot': {'min': -0.01497301416312933,
#      'q1': 0.3339581527738025,
#      'median': 0.48167900124499363,
#      'q3': 0.5578492072066206,
#      'max': 0.6126735581956356}},
#    'M3': {'average_score': 0.5015402386734947,
#     'boxplot': {'min': -0.01997816997466422,
#      'q1': 0.36045066307689,
#      'median': 0.60101912572177,
#      'q3': 0.6423262223285457,
#      'max': 0.6839860669788265}},
#    'R18': {'average_score': 0.43207209488838677,
#     'boxplot': {'min': -0.01700954521980436,
#      'q1': 0.3488989863175699,
#      'median': 0.48269285914786897,
#      'q3': 0.5817445583647545,
#      'max': 0.6194627778600535}},
#    'A8': {'average_score': 0.6012734707094833,
#     'boxplot': {'min': -0.057959670083659244,
#      'q1': 0.5383564665331265,
#      'median': 0.6421313496151507,
#      'q3': 0.7325667556693295,
#      'max': 0.7613844742670542}},
#    'R19': {'average_score': 0.4391121879990696,
#     'boxplot': {'min': -0.17410006062812725,
#      'q1': 0.3610928582178079,
#      'median': 0.4886866519859446,
#      'q3': 0.5457337367232611,
#      'max': 0.6058129850194421}}}}}

# %% [markdown]
# #### Using Density clustering (dbscan) to calculate silhouette score for each skill (individual class)[USED on PAPER]

# %%
import numpy as np
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.cluster import DBSCAN
import json

def compute_silhouette_scores(data, method_name):
    # Initialize results dictionary
    results = {}
    
    # Get unique methods
    methods = set(d['method'] for d in data)
    
    for method in methods:
        # Filter data based on the method
        method_data = [d for d in data if d['method'] == method]
        
        # Extract x, y positions and skill labels
        positions = np.array([(d['x'], d['y']) for d in method_data])
        labels = np.array([d['skill'] for d in method_data])
        
        # Ensure there are at least two unique labels (skills)
        if len(set(labels)) > 1:
            # Compute overall silhouette score using skill labels as clusters
            silhouette_values = silhouette_samples(positions, labels, metric='euclidean')
            average_score = silhouette_score(positions, labels, metric='euclidean')
            boxplot_stats = calculate_boxplot_stats(silhouette_values)
            
            # Initialize method results
            method_results = {
                'average_score': average_score,
                'boxplot': boxplot_stats,
                'skills': {}
            }
            
            # Calculate silhouette score for each skill (individual class) using DBSCAN
            skills = set(labels)
            for skill in skills:
                # Filter data for the specific skill
                skill_data = np.array([pos for pos, lbl in zip(positions, labels) if lbl == skill])
                
                # Apply DBSCAN clustering to get cluster labels for skill data
                if len(skill_data) > 1:
                    dbscan = DBSCAN(eps=0.5, min_samples=5).fit(skill_data)
                    skill_labels = dbscan.labels_
                    
                    # Check if DBSCAN found at least two clusters
                    unique_labels = set(skill_labels)
                    if len(unique_labels) > 1 and -1 in unique_labels:
                        unique_labels.remove(-1)  # Ignore noise label
                    
                    if len(unique_labels) > 1:  # Only proceed if there are at least two clusters
                        # Filter out noise points (label -1)
                        non_noise_indices = skill_labels != -1
                        filtered_skill_data = skill_data[non_noise_indices]
                        filtered_skill_labels = skill_labels[non_noise_indices]
                        
                        # Compute silhouette score for skill data without noise
                        skill_silhouette_values = silhouette_samples(filtered_skill_data, filtered_skill_labels, metric='euclidean')
                        skill_average_score = silhouette_score(filtered_skill_data, filtered_skill_labels, metric='euclidean')
                        skill_boxplot_stats = calculate_boxplot_stats(skill_silhouette_values)
                        
                        # Store skill results
                        method_results['skills'][skill] = {
                            'average_score': skill_average_score,
                            'boxplot': skill_boxplot_stats
                        }
            
            # Store method results in the main results dictionary
            results[method] = method_results
    
    # Save results to a JSON file
    silhouette_path = path_raw_data + f"/silhouette_scores_dbscan_{method_name}.json"
    with open(silhouette_path, 'w') as outfile:
        json.dump(results, outfile, indent=4)
    
    return results

def calculate_boxplot_stats(data):
    # Sort data
    sorted_data = np.sort(data)
    
    # Calculate quartiles
    q1 = np.percentile(sorted_data, 25)
    median = np.percentile(sorted_data, 50)
    q3 = np.percentile(sorted_data, 75)
    min_value = sorted_data[0]
    max_value = sorted_data[-1]
    
    return {
        'min': min_value,
        'q1': q1,
        'median': median,
        'q3': q3,
        'max': max_value
    }

def compute_for_all_projections(all_pca_data, all_tsne_data, all_umap_data):
    compute_silhouette_scores(all_pca_data, 'pca')
    compute_silhouette_scores(all_tsne_data, 'tsne')
    compute_silhouette_scores(all_umap_data, 'umap')

# Example of calling the function with data
compute_for_all_projections(all_pca_data, all_tsne_data, all_umap_data)

# %% [markdown]
# ## Similarity measurements

# %% [markdown]
# #### Using projected space (ex. x and y positions based on tSNE)

# %%
import os
import pandas as pd

# Define the root directory containing the CSV folders
root_dir = "/Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/similarity/csv"
output_csv = root_dir + "/combined_jaccard_index.csv"
import os
import pandas as pd

# Define the root directory containing the CSV folders
root_dir = "/Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/similarity/csv"

# Define the output file paths for each of the CSVs
output_files = {
    "1s": root_dir + "/combined_jaccard_index_1s.csv",
    "2s": root_dir + "/combined_jaccard_index_2s.csv",
    "4s": root_dir + "/combined_jaccard_index_4s.csv"
}

# Iterate over each subfolder (1s, 2s, 4s)
for subfolder, output_csv in output_files.items():
    # Initialize an empty DataFrame to hold all the data for the current subfolder
    combined_df = pd.DataFrame()

    # Construct the full path to the subfolder
    subfolder_path = os.path.join(root_dir, subfolder)

    # Iterate over files in the subfolder
    for file in os.listdir(subfolder_path):
        if file.endswith("_jaccard_index.csv"):
            # Extract skill from the filename
            skill = file.split('_')[0]
            
            # Read the CSV file into a DataFrame
            file_path = os.path.join(subfolder_path, file)
            df = pd.read_csv(file_path)
            
            # Add the 'skill' column to the DataFrame
            df.insert(0, 'skill', skill)
            
            # Append the DataFrame to the combined DataFrame
            combined_df = pd.concat([combined_df, df], ignore_index=True)

    # Save the combined DataFrame to a new CSV file for the current subfolder
    combined_df.to_csv(output_csv, index=False)

    print(f"Combined CSV file for {subfolder} saved to {output_csv}")
# Out:
# Combined CSV file for 1s saved to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/similarity/csv/combined_jaccard_index_1s.csv
# Combined CSV file for 2s saved to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/similarity/csv/combined_jaccard_index_2s.csv
# Combined CSV file for 4s saved to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/similarity/csv/combined_jaccard_index_4s.csv

# %% [markdown]
# #### Using original high dimensional space [USED on PAPER]

# %%
import os
import pandas as pd

# Define the root directory containing the CSV folders
root_dir = "/Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/highdimensional_space_similarity/csv"
output_csv = root_dir + "/combined_jaccard_index.csv"
import os
import pandas as pd

# Define the root directory containing the CSV folders
root_dir = "/Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/highdimensional_space_similarity/csv"

# Define the output file paths for each of the CSVs
output_files = {
    "1s": root_dir + "/combined_jaccard_original_space_index_1s.csv",
    "2s": root_dir + "/combined_jaccard_original_space_index_2s.csv",
    "4s": root_dir + "/combined_jaccard_original_space_index_4s.csv"
}

# Iterate over each subfolder (1s, 2s, 4s)
for subfolder, output_csv in output_files.items():
    # Initialize an empty DataFrame to hold all the data for the current subfolder
    combined_df = pd.DataFrame()

    # Construct the full path to the subfolder
    subfolder_path = os.path.join(root_dir, subfolder)

    # Iterate over files in the subfolder
    for file in os.listdir(subfolder_path):
        if file.endswith("jaccard_index_original_space.csv"):
            # Extract skill from the filename
            skill = file.split('_')[0]
            
            # Read the CSV file into a DataFrame
            file_path = os.path.join(subfolder_path, file)
            df = pd.read_csv(file_path)
            
            # Add the 'skill' column to the DataFrame
            df.insert(0, 'skill', skill)
            
            # Append the DataFrame to the combined DataFrame
            combined_df = pd.concat([combined_df, df], ignore_index=True)

    # Save the combined DataFrame to a new CSV file for the current subfolder
    combined_df.to_csv(output_csv, index=False)

    print(f"Combined CSV file for {subfolder} saved to {output_csv}")
# Out:
# Combined CSV file for 1s saved to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/highdimensional_space_similarity/csv/combined_jaccard_original_space_index_1s.csv
# Combined CSV file for 2s saved to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/highdimensional_space_similarity/csv/combined_jaccard_original_space_index_2s.csv
# Combined CSV file for 4s saved to /Users/soniacq/PTG/BBN_data/updated_models/different_windows_size/highdimensional_space_similarity/csv/combined_jaccard_original_space_index_4s.csv

# %%
# !pip install umap-learn
# Out:
# Collecting umap-learn
#   Using cached umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/miniconda3/envs/bbn/lib/python3.12/site-packages (from umap-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /opt/miniconda3/envs/bbn/lib/python3.12/site-packages (from umap-learn) (1.13.0)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/miniconda3/envs/bbn/lib/python3.12/site-packages (from umap-learn) (1.4.2)
# Collecting numba>=0.51.2 (from umap-learn)
#   Using cached numba-0.60.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (2.7 kB)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Using cached pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Collecting tqdm (from umap-learn)
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.9 MB/s eta 0:00:00
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba>=0.51.2->umap-learn)
#   Using cached llvmlite-0.43.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: joblib>=0.11 in /opt/miniconda3/envs/bbn/lib/python3.12/site-packages (from pynndescent>=0.5->umap-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/miniconda3/envs/bbn/lib/python3.12/site-packages (from scikit-learn>=0.22->umap-learn) (2.2.0)
# Using cached umap_learn-0.5.6-py3-none-any.whl (85 kB)
# Using cached numba-0.60.0-cp312-cp312-macosx_10_9_x86_64.whl (2.6 MB)
# Using cached pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 8.2 MB/s eta 0:00:00
# Using cached llvmlite-0.43.0-cp312-cp312-macosx_10_9_x86_64.whl (31.1 MB)
# Installing collected packages: tqdm, llvmlite, numba, pynndescent, umap-learn
# Successfully installed llvmlite-0.43.0 numba-0.60.0 pynndescent-0.5.13 tqdm-4.66.5 umap-learn-0.5.6
